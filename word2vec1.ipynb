# %%
from gensim.models import Word2Vec
import numpy as np
import codecs
import pandas as pd
import re

# %% [markdown]
# # read data

# %%
df = pd.read_excel('book4.xlsx', header=None)
df.columns = ['comment']
df.head()
# Out:
#                                              comment
# 0                                             سلام .
# 1  با توجه به قیمت و انتظاراتی که از یک هتل ۵ ستا...
# 2      نظافت اطاقها در حد هتل سه ستاره‌های دبی بود .
# 3                                غذا خیلی گران بود .
# 4  سرویس اتاق آنقدر با تاخیر می‌آمد که مجبور بودی...

# %% [markdown]
# # preprocess

# %%
from parsivar import Normalizer
my_normalizer = Normalizer()

# %%
def normalize(txt):
    tmp = re.sub(r'[?|$|.|!|-|_|:|,|،|)|(]', r'', txt)
    return my_normalizer.normalize(tmp)

# %%
df['normalized_txt'] = df['comment'].apply(normalize)

# %%
df.head()
# Out:
#                                              comment  \
# 0                                             سلام .
# 1  با توجه به قیمت و انتظاراتی که از یک هتل ۵ ستا...
# 2      نظافت اطاقها در حد هتل سه ستاره‌های دبی بود .
# 3                                غذا خیلی گران بود .
# 4  سرویس اتاق آنقدر با تاخیر می‌آمد که مجبور بودی...
#
#                                       normalized_txt
# 0                                               سلام
# 1  با توجه به قیمت و انتظاراتی که از یک هتل 5 ستا...
# 2        نظافت اطاقها در حد هتل سه ستاره‌های دبی بود
# 3                                  غذا خیلی گران بود
# 4  سرویس اتاق آنقدر با تاخیر می‌آمد که مجبور‌بودی...

# %%
from parsivar import Tokenizer
my_tokenizer = Tokenizer()

# %%
def divide_to_tokens(tmp_text):
    words = my_tokenizer.tokenize_words(my_normalizer.normalize(tmp_text))
    return words

# %%
def divide_to_sents(tmp_text):
    sents = my_tokenizer.tokenize_sentences(my_normalizer.normalize(tmp_text))
    return sents

# %%
corpus = []
for index, row in df.iterrows():
    word_list = divide_to_tokens(row['normalized_txt'])
    corpus.append(word_list)

# %%
corpus
# Out:
# [['سلام'],
#  ['با',
#   'توجه',
#   'به',
#   'قیمت',
#   'و',
#   'انتظاراتی',
#   'که',
#   'از',
#   'یک',
#   'هتل',
#   '5',
#   'ستاره',
#   'داریم',
#   'اصلا',
#   'و',
#   'ابدا',
#   'خوب',
#   'نبود'],
#  ['نظافت', 'اطاقها', 'در', 'حد', 'هتل', 'سه', 'ستاره\u200cهای', 'دبی', 'بود'],
#  ['غذا', 'خیلی', 'گران', 'بود'],
#  ['سرویس',
#   'اتاق',
#   'آنقدر',
#   'با',
#   'تاخیر',
#   'می\u200cآمد',
#   'که',
#   'مجبور\u200cبودیم',
#   'سفارش',
#   'را',
#   'لغو',
#   'کنیم'],
#  ['ظروف', 'رستوران', 'قدیمی', 'کدر', 'بود'],
#  ['آکسسوار', 'اطاقها', 'قدیمی', 'بود'],
#  ['جدیدها', 'هم', 'از', 'کیفیت', 'پائینی', 'برخوردار', 'بود'],
#  ['اگر', 'انعام', 'می\u200cدادیم', 'رفتار', 'پرسنل', 'خوب', 'بود'],
#  ['در',
#   'غیر',
#   'اینصورت',
#   'رفتارشان',
#   'خیلی',
#   'بدوی',
#   'و',
#   'روستایی',
#   'مآبانه',
#   'بود'],
#  ['رستوران', 'ایتالیایی', 'دارای', 'کارکنان', 'نیمه', 'حرفه', 'ایی'],
#  ['تا', 'حدی', 'قابل', 'قبول', 'بود'],
#  ['به', 'صورت', 'اسمی', 'خانه\u200cداری', '24', 'ساعته', 'بود'],
#  ['ساعت',
#   '9',
#   'شب',
#   'که',
#   'درخواست',
#   'آب',
#   'معدنی',
#   'کردم',
#   'ساعت',
#   '11',
#   'شب',
#   'آوردند'],
#  ['من',
#   'هم',
#   'نپذیرفتم',
#   'ولی',
#   'در',
#   'موقع',
#   'تسویه',
#   'حساب',
#   'هم',
#   'با',
#   'من',
#   'حساب',
#   'کرده',
#   'بودند'],
#  ['100',
#   'درصد',
#   'مطمئن',
#   'هستم',
#   'اگر',
#   'واقعا',
#   'به',
#   'بخش',
#   'خصوصی',
#   'واگذار',
#   'کنند',
#   'کیفیت',
#   'ارائه',
#   'خدمات',
#   'به',
#   'نحو',
#   'چشمگیری',
#   'افزایش',
#   'پیدا',
#   'می\u200cکند'],
#  ['نزدیک', 'نمایشگاه'],
#  ['نکته', 'خاص', 'برای', 'من', 'رستوران', 'ایتالیایی', 'آن', 'بود'],
#  ['رفتار', 'پرسنل', 'حرفه\u200cای', 'بود'],
#  ['که', 'کمتر', 'در', 'هتل\u200cهای', 'ایران', 'دیده', 'می\u200cشود'],
#  ['در',
#   'یکی',
#   'از',
#   'سفرهای',
#   'کاری',
#   'آقای',
#   'علی',
#   'دایی',
#   'و',
#   'تیمش',
#   'که',
#   'فکر',
#   'کنم',
#   'آن',
#   'موقع',
#   'پرسپولیس\u200cبود',
#   'در',
#   'هتل',
#   'بودند'],
#  ['دو',
#   'سال',
#   'پشت',
#   'سر',
#   'هم',
#   'برای',
#   'دو',
#   'روز',
#   'و',
#   'چهار',
#   'روز',
#   'در',
#   'این',
#   'هتل',
#   'اقامت',
#   'داشتم'],
#  ['به\u200cطور', 'کلی', 'هتل', 'رو', 'دوست', 'داشتم'],
#  ['البته',
#   'امسال',
#   'به',
#   'علت',
#   'قیمت',
#   'بالا',
#   'هتل',
#   'دیگری',
#   'را',
#   'انتخاب',
#   'می\u200cکنم'],
#  ['اتاق\u200cها', 'خوب', 'گردگیری\u200cنشده\u200cبود'],
#  ['کف', 'اتاق', 'هم', 'موکت\u200cها', 'خیلی', 'تمیز', 'نبود'],
#  ['برنامه', 'استخرها', 'خوب', 'نبود'],
#  ['مخصوصا', 'برای', 'خانم\u200cها'],
#  ['یک', 'بار', 'هم', 'استخر', 'در', 'دست', 'تعمیر', 'بود'],
#  ['به', 'نظر', 'من', 'به', 'پنج', 'ستاره', 'نمی\u200cخورد'],
#  ['کیفیت', 'اتاق', 'معمولی', 'هست'],
#  ['کارکنان', 'خوش', 'برخوردی', 'دارد'],
#  ['کیفیت', 'غذا', 'معمولی', 'هست', 'نه', 'بیشتر'],
#  ['سرویس',
#   'و',
#   'آماده\u200cسازی',
#   'غذا',
#   'چه',
#   'درون',
#   'اتاق',
#   'و',
#   'چه',
#   'در',
#   'رستوران',
#   'با',
#   'کمی',
#   'تاخیر',
#   'انجام',
#   'می\u200cشود'],
#  ['فضاسازی',
#   'و',
#   'استفاده',
#   'از',
#   'طبیعیت',
#   'محوطه',
#   'هتل',
#   'باید',
#   'بیشتر',
#   'و',
#   'بهتر',
#   'باشد'],
#  ['موقع',
#   'مراجعه',
#   'به',
#   'هتل',
#   'کادر',
#   'هتل',
#   'گفتند',
#   'اتاقتان',
#   'آماده',
#   'نیست'],
#  ['چند', 'ساعت', 'در', 'لابی', 'منتظر', 'ماندیم'],
#  ['سرویس', 'فرنگی', 'هم', 'خراب', 'بود'],
#  ['مجبور', 'شدیم', 'اتاق', 'را', 'عوض', 'کنیم'],
#  ['اصلا', 'راضی', 'نبودیم'],
#  ['به', 'نظر', 'من', 'بسیار', 'هتل', 'عالی', 'است'],
#  ['جز', 'رستوران', 'گردان', 'آن', 'همه', 'چیز', 'عالی', 'است'],
#  ['از',
#   'هتل',
#   '4',
#   'ستاره',
#   'انتظار',
#   'می\u200cرود',
#   'در',
#   'اتاق',
#   'چای',
#   'ساز',
#   'باشد'],
#  ['صبحانه', 'عالی', 'بود'],
#  ['سریعا', 'ظروف', 'شارژ', 'می\u200cشد'],
#  ['محیط', 'اتاق', 'خوب', 'بود'],
#  ['اتاق', 'نور', 'کافی', 'نداشت'],
#  ['حمام', 'خیلی', 'کوچک', 'بود'],
#  ['اتاق\u200cها', 'قدیمی'],
#  ['از', 'نور', 'کافی', 'برخوردار', 'نیست'],
#  ['قبلا', 'داخل', 'اتاق', 'چای', 'ساز', 'نداشت'],
#  ['جدیدا', 'این', 'مشکل', 'رفع\u200cشده\u200cاست'],
#  ['از',
#   'هتل',
#   '4',
#   'ستاره',
#   'با',
#   'سابقه',
#   'کار',
#   'بسیار',
#   'انتظار',
#   'ارائه',
#   'خدمات',
#   'بیشتر',
#   'و',
#   'بهتر',
#   'دارم'],
#  ['سلام'],
#  ['محیطی', 'بسیار', 'تمیز'],
#  ['کارمندان', 'مودب'],
#  ['با', 'غذا\u200cهای', 'خوشمزه'],
#  ['باکیفیت'],
#  ['با', 'قیمت', 'مناسب'],
#  ['خسته', 'نباشید'],
#  ['امکانات', 'درحد', '5ستاره', 'نیست'],
#  ['ظاهرخوبی', 'دارد'],
#  ['محل', 'قرارگیری', 'شلوغ'],
#  ['الودگی', 'صوتی', 'وبصری', 'هوا', 'زیاد', 'هست'],
#  ['عالی'],
#  ['خیلی', 'عالی', 'است'],
#  ['من', 'از', 'همه', 'چیز', 'آن', 'خوشم', 'آمد'],
#  ['هتل', 'عباسی', 'بسیار', 'شیک', 'وزیبا', 'بود'],
#  ['من', 'از', 'اتاق', 'و', 'برخورد', 'کارکنان', 'راضی', 'بودم'],
#  ['محیط', 'لابی', 'و', 'حیاط', 'جذاب', 'هست'],
#  ['دو', 'نکته', 'منفی', 'در', 'این', 'هتل', 'دیدم'],
#  ['مهمان\u200c\u200cهای', 'غیر', 'مقیم', 'زیاد', 'هستند'],
#  ['ما', 'برای', 'خالی', 'شدن', 'میز', 'شام', 'معطل', 'شدیم'],
#  ['کاملا',
#   'قید',
#   'قسمت',
#   'کافی\u200cشاپ',
#   'و',
#   'قهوه',
#   'خانه',
#   'سنتی',
#   'را',
#   'زدیم'],
#  ['دقیقا', 'مثل', 'اینکه', 'مهمان', 'دعوت', 'کنید'],
#  ['برای',
#   'عقد',
#   'بعد',
#   'از',
#   'اینکه',
#   'مهمان',
#   'کادو',
#   'را',
#   'داد',
#   'خانواده',
#   'درجه',
#   'یک',
#   'همه',
#   'بنشینند',
#   'روی',
#   'مبل',
#   'بعد',
#   'مهمان',
#   'غریبه',
#   'وسط',
#   'مجلس',
#   'بایستید'],
#  ['در',
#   'قسمت',
#   'صبحانه',
#   'ما',
#   'نزدیک',
#   'به',
#   'ساعت',
#   'پایانی',
#   'کار',
#   'رستوران',
#   'آنجا',
#   'بودیم'],
#  ['بنده',
#   'دیدم',
#   'یکی',
#   'از',
#   'پیشخدمت\u200c\u200cها',
#   'قسمت',
#   'زیرین',
#   'محفظه\u200cای',
#   'که',
#   'درون',
#   'آن',
#   'آب',
#   'پرتقال',
#   'وجود',
#   'دارد',
#   'و',
#   'در',
#   'واقع',
#   'مقداری',
#   'که',
#   'سر\u200cریز',
#   'می\u200cشود',
#   'درونش',
#   'ریخته',
#   'می\u200cشود',
#   'را',
#   'برگرداند',
#   'دوباره',
#   'در',
#   'ظرف'],
#  ['همه', 'چیز', 'عالی'],
#  ['مخصوصا', 'فضای', 'سبز'],
#  ['آثار', 'قدیمی'],
#  ['اطاق', '1220', 'بعنوان', 'یک', 'سوییت', 'نمی\u200cباشد'],
#  ['اطاق', '1008', 'یک', 'سوییت', 'کامل', 'بود'],
#  ['عالی'],
#  ['خوب', 'بود'],
#  ['اگر',
#   'پرسنلش',
#   'اینقدر',
#   'بهانه',
#   'دولتی',
#   'بودن',
#   'نمی\u200cکردند',
#   'حداقل',
#   'این',
#   'هتل',
#   'خصوصی',
#   'می\u200cشد'],
#  ['افتضاح'],
#  ['برخورد', 'بد', 'پرسنل'],
#  ['اتاق\u200c\u200cها',
#   'از',
#   'ابتدائی\u200c\u200cترین',
#   'امکانات',
#   'بی\u200cبهره',
#   'است'],
#  ['قبل', 'از', 'انقلاب', 'واقعا', '5', 'ستاره', 'بود'],
#  ['الان', 'در', 'حد', 'یک', 'مسافرخانه', 'هم', 'نیست'],
#  ['ما', 'همان', 'شب', 'اول', 'به', 'هتل', 'دیگری', 'رفتیم'],
#  ['خیلی', 'جالب', 'نبود'],
#  ['ما', 'از', 'هتل', 'عباسی', 'انتظارآن', 'را', 'نداشتیم'],
#  ['در', 'پارک', 'خوابیدن', 'از', 'این', 'هتل', 'بهتر', 'است'],
#  ['قیمت', 'هتل', 'با', 'توجه', 'به', 'امکانات', 'بالا', 'است'],
#  ['در', 'اصفهان', 'بهتر', 'از', 'این', 'هتل', 'گزینه', 'دیگری', 'نیست'],
#  ['صبحانه',
#   'هتل',
#   'بسیار',
#   'عالی',
#   'و',
#   'متمایز',
#   'از',
#   'هتل\u200c\u200cهای',
#   'دیگر',
#   'اصفهان',
#   'است'],
#  ['پارکینگ', 'هتل', 'فضایش', 'بسیار', 'کم', 'است'],
#  ['برای', 'پارک', 'خودرو', 'جا', 'ندارد'],
#  ['افتضاح', 'بود'],
#  ['اصلا', 'درحدهتل', '5', 'ستاره', 'نیست'],
#  ['3', 'ستاره', 'هم', 'برایش', 'زیاد', 'است'],
#  ['همه', 'چه', 'در', 'این', 'هتل', 'بد', 'بود'],
#  ['از', 'دربان', 'گرفته', 'تا', 'پذیرش', 'و', 'رستوران'],
#  ['با',
#   'توجه',
#   'به',
#   'امکانات',
#   'اتاق',
#   'رفتن',
#   'به',
#   'این',
#   'هتل',
#   'را',
#   'پیشنهاد',
#   'نمی\u200cکنم'],
#  ['اصلا', 'باورکردنی', 'نبود'],
#  ['هتل', 'خیلی', 'زیبا', 'ورویایی', 'بود'],
#  ['واقعا', 'من', 'دلم', 'نمی\u200cخواست', 'از', 'هتل', 'بیرون', 'بروم'],
#  ['توصیه',
#   'می\u200cکنم',
#   'حتما',
#   'برای',
#   'اقامت',
#   'در',
#   'اصفهان',
#   'از',
#   'هتل',
#   'عباسی',
#   'استفاده',
#   'کنید'],
#  ['در', 'رستوران', 'سنتی', 'بسیار', 'غذا', 'مانده', 'و', 'فاسد', 'بود'],
#  ['طوری',
#   'که',
#   'از',
#   '6',
#   'نفر',
#   'ما',
#   '5',
#   'نفر',
#   'آن',
#   'شب',
#   'مسموم',
#   'شدیم'],
#  ['از', 'یک', 'همچنین', 'هتل', 'و', 'رستورانی', 'انتظاری', 'نمی\u200cرفت'],
#  ['هتل', 'بسیار', 'زیبایی', 'است'],
#  ['سرویس', 'و', 'نحوه', 'برخورد', 'کارکنان', 'عالی', 'بود'],
#  ['تنها',
#   'موردی',
#   'که',
#   'خوشایند',
#   'نبود',
#   'درمورد',
#   'رزرواسیون',
#   'وتحویل',
#   'اتاق',
#   'بود'],
#  ['ما', 'آپارتمان', 'چهارنفره', 'رزروکرده', 'بودیم'],
#  ['به', 'ما', 'دو', 'اتاق', 'دو', 'نفره', 'معمولی', 'دادند'],
#  ['نکته',
#   'مهم',
#   'اینکه',
#   'تفاوت',
#   'قیمت',
#   'اتاق',
#   'را',
#   'به',
#   'ما',
#   'پرداخت',
#   'نکردند'],
#  ['از', 'همه', 'نظر', 'بد', 'بود'],
#  ['عالی', 'بود'],
#  ['گران'],
#  ['یک', 'هتل', 'رویائی'],
#  ['رویایی', 'بود'],
#  ['مرسی'],
#  ['هتل', 'از', 'فضای', 'خوبی', 'برخوردار', 'است'],
#  ['حس', 'خوبی', 'به', 'آدم', 'می\u200cدهد'],
#  ['اتاق\u200c\u200cها', 'اصلا', 'در', 'حد', 'یک', 'هتل', '5', 'ستاره', 'نیست'],
#  ['حداکثر',
#   'می\u200cتوان',
#   'تصور',
#   'کرد',
#   'که',
#   'در',
#   'یک',
#   'مسافرخانه',
#   '3',
#   'ستاره',
#   'هستید'],
#  ['فضای', 'باز', 'و', 'محیط', 'رستوران', 'آن', 'بسیار', 'عالی', 'است'],
#  ['هجوم', 'میهمان\u200cها', 'بیش', 'از', 'حد', 'است'],
#  ['خارج', 'از', 'آرامش', 'میهمانان', 'هتل', 'است'],
#  ['برخورد', 'پرسنل', 'بسیار', 'خوب', 'ومهمان', 'نوازانه', 'بود'],
#  ['ممنون'],
#  ['اقامت', 'در', 'اوین', '4', 'ستاره', 'حس', 'خیلی', 'بهتری', 'دارد'],
#  ['نسبت',
#   'به',
#   'بعضی',
#   'هتل\u200c\u200cهای',
#   '5',
#   'ستاره',
#   'تهران',
#   'داشتن',
#   'رستوران',
#   'خوب',
#   'محیط',
#   'دلچسب',
#   'و',
#   'تمیز',
#   'سرویس\u200cدهی',
#   'خوب',
#   'اتاق\u200c\u200cهای',
#   'نسبتا',
#   'مجهز',
#   'از',
#   'امتیاز\u200c\u200cهای',
#   'اوین',
#   'هست'],
#  ['من', 'برای', '3', 'شب', 'در', 'این', 'هتل', 'اقامت', 'داشتم'],
#  ['از', 'همه', 'امکاناتش', 'استفاده', 'کردم'],
#  ['راضی', 'بودم'],
#  ['بیشتر', 'از', 'این', 'انتظار', 'داشتم'],
#  ['در',
#   'کشور\u200cهای',
#   'دبی',
#   'آنتالیا',
#   'جزایر',
#   'هاوایی',
#   'که',
#   'رفته\u200cبودم',
#   'در',
#   'قیاس',
#   'با',
#   'آنجا',
#   'اینجا',
#   'از',
#   'متوسط',
#   'هم',
#   'پایین\u200c\u200cتر',
#   'بود'],
#  ['عالی'],
#  ['کم', 'نظیر'],
#  ['در', 'حد', 'بی\u200cنظیر'],
#  ['کادرجنتلمن', 'واقعی'],
#  ['خدمات', '20'],
#  ['منوی', 'صبحانه', 'متنوع', 'و', 'کارشناسی\u200cشده'],
#  ['تنها', 'گاهی', 'اوقات', 'یک', 'صدای', 'متناوب', 'به', 'گوش', 'میرسید'],
#  ['حدس', 'من', 'خرابی', 'یکی', 'از', 'آسانسور\u200cها', 'بود'],
#  ['در', 'کل', 'واقعا', 'جای', 'تشکر', 'و', 'دست', 'مریزاد', 'دارد'],
#  ['عالی'],
#  ['واقعا', 'عالی'],
#  ['محیط', 'هتل', 'خوب', 'بود'],
#  ['یکی',
#   'از',
#   'اشکالها\u200cی',
#   'بزرگ',
#   'شلوغی',
#   'بیش',
#   'از',
#   'حد',
#   'لابی',
#   'هتل',
#   'بود'],
#  ['انسان', 'احساس', 'آرامش', 'نداشت'],
#  ['به', 'هیچ', 'وجه', 'حالت', 'اتاق', 'انتظار', 'داشت'],
#  ['مسافر', 'احساس', 'راحتی', 'و', 'آرامش', 'ندارد'],
#  ['هیچ', 'خوراکی', 'سرو', 'نمی\u200cشود'],
#  ['من', 'در', 'این', 'مورد', 'سوال', 'کردم'],
#  ['رسپشن', 'خیلی', 'با', 'تندی', 'جواب', 'داد'],
#  ['خیر', 'سرو', 'نمی\u200cشود'],
#  ['هتل', 'خوب', 'و', 'تمیزی', 'بود'],
#  ['خصوصا', 'که', 'زنده', 'رود', 'جاری', 'بود'],
#  ['نمای', 'زیبایی', 'از', 'هتل', 'داشت'],
#  ['به',
#   'نسبت',
#   'تعداد',
#   'میهمان',
#   'هتل',
#   'سالن',
#   'صبحانه',
#   'بسیار',
#   'کوچک',
#   'بود'],
#  ['من', 'صبحانه', 'این', 'هتل', 'را', 'خوردم'],
#  ['در',
#   'طبقه',
#   '14',
#   'هتل',
#   'با',
#   'نمایی',
#   'زیبا',
#   'از',
#   'شهر',
#   'مشهد',
#   'دارد'],
#  ['انتظارم',
#   'از',
#   'سرویس',
#   'صبحانه',
#   'این',
#   'هتل',
#   'مجلل',
#   'کمی',
#   'بیشتر',
#   'بود'],
#  ['ممنون', 'از', 'رزرواسیون', 'مهر'],
#  ['هتل', 'فوق\u200cالعاده', 'خوب'],
#  ['باتشکر', 'از', 'خدمات'],
#  ['امکانات', 'خوب'],
#  ['همچنین', 'کارمندان', 'باشعور'],
#  ['عالی'],
#  ['عالی'],
#  ['عالی'],
#  ['بسیار', 'هتل', 'خوبی', 'بود'],
#  ['حتما', 'سفر', 'بعدی', 'هم', 'از', 'این', 'هتل', 'استفاده', 'می\u200cکنم'],
#  ['برخورد',
#   'پرسنل',
#   'امکانات',
#   'تمیزی',
#   'ترانسفر',
#   'و',
#   'بدرقه',
#   'و',
#   'مجموعه',
#   'آبی',
#   'همه',
#   'عالی',
#   'بودند'],
#  ['توصیه', 'می\u200cکنم', 'یک', 'بار', 'امتحان', 'کنید'],
#  ['بهشتی\u200cبود', 'واسه', 'خودش'],
#  ['من',
#   'و',
#   'همسرم',
#   'یک',
#   'شب',
#   'خوب',
#   'و',
#   'به',
#   'یاد',
#   'ماندنی',
#   'را',
#   'تجربه',
#   'کردیم'],
#  ['در',
#   'این',
#   'هتل',
#   'درست',
#   'هست',
#   'یک',
#   'شب',
#   'بیشتر',
#   'نبودیم',
#   'فک',
#   'می\u200cکنم',
#   'بهترین',
#   'انتحاب',
#   'برای',
#   'ما',
#   'بود'],
#  ['پیشنهاد',
#   'می\u200cکنم',
#   'یک',
#   'همچین',
#   'هتل',
#   'مجللی',
#   'را',
#   'تجربه',
#   'کنید'],
#  ['واقعا', 'از', 'اقامتم', 'در', 'این', 'هتل', 'راضی', 'هستم'],
#  ['کیفیت', 'کار', 'بالایی', 'را', 'شاهد', 'بودم'],
#  ['از',
#   'پوشش',
#   'لباس',
#   'کارمندان',
#   'تا',
#   'سرو',
#   'و',
#   'پذیرایی',
#   'خوراک',
#   'در',
#   'رستوران',
#   'همه',
#   'عالی',
#   'بودن'],
#  ['تشکر'],
#  ['با',
#   'توجه',
#   'به',
#   'امکانات',
#   'بهتر',
#   'از',
#   'آن',
#   'هتل',
#   'قیمت',
#   'مناسب\u200cتری',
#   'هم',
#   'داشت'],
#  ['من',
#   'تا',
#   'حالا',
#   'از',
#   'طبقه',
#   '14',
#   'به',
#   'پایین',
#   'نگاه',
#   'نکرده',
#   'بودم'],
#  ['اتفاقا', 'پوشش', 'چادری', 'خوب', 'هست'],
#  ['این', 'هتل', 'را', 'من', 'نرفتم'],
#  ['داییم', 'رفته', 'و', 'زیاد', 'تعریف', 'می\u200cکند'],
#  ['این', 'هم', 'قیمت', 'خیلی', 'بالا', 'است'],
#  ['این', 'هتل', 'واقعا', 'خوب', 'هست'],
#  ['من', 'همیشه', 'در', 'مشهد', 'به', 'این', 'هتل', 'می\u200cروم'],
#  ['هتل', 'خوب\u200cبود', 'مخصوصا', 'مجموعه', 'استخر'],
#  ['اطلاع\u200cرسانی',
#   'در',
#   'اتاق',
#   'درباره',
#   'قسمت\u200cهای',
#   'مختلف',
#   'هتل',
#   'خیلی',
#   'کم',
#   'بود'],
#  ['در', 'ضمن', 'پوشش', 'به', 'سبک', 'عربی', 'بود'],
#  ['برای',
#   'ما',
#   'ایرانی\u200cها',
#   'با',
#   'پیشینه',
#   'تاریخی',
#   'و',
#   'باستانی',
#   'جالب',
#   'نیست'],
#  ['محیط', 'لابی', 'خیلی', 'خوب', 'بود'],
#  ['در', 'مجموع', 'خوب', 'بود'],
#  ['می\u200cتواند', 'خیلی', 'بهتر', 'باشد'],
#  ['واقعا', 'از', 'آقای', 'درویشی', 'ممنون'],
#  ['برای', 'هتل', 'خوب'],
#  ['برای', 'ایشان', 'آرزوی', 'سلامتی', 'سربلندی', 'و', 'پیروزی', 'می\u200cکنم'],
#  ['سلام'],
#  ['هتل', 'خوبی', 'بود'],
#  ['آن', 'جوری', 'که', 'تعریفش', 'را', 'شنیدم', 'نبود'],
#  ['هتل', '٥', 'ستاره', 'تاپ', 'محسوب', 'می\u200cشود'],
#  ['می\u200cتوانست', 'خیلی', 'بهتر', 'از', 'این\u200cها', 'باشد'],
#  ['ضعف\u200cهای', 'زیادی', 'دارد'],
#  ['من', 'و', 'دوستانم', '2', 'شب', 'در', 'این', 'هتل', 'اقامت', 'داشتیم'],
#  ['مدیریت',
#   'و',
#   'کلاس',
#   'هتل',
#   'هما',
#   'قابل',
#   'مقایسه',
#   'با',
#   'این',
#   'هتل',
#   'نیست'],
#  ['فکر', 'کنم', 'این', 'هتل', 'صرفا', 'برای', 'عرب\u200cها', 'ساخته\u200cشده'],
#  ['باب', 'طبع', 'آن\u200cها', 'است'],
#  ['هتل', 'معماری', 'و', 'دکوراسیون', 'بسیار', 'مدرنی', 'دارد'],
#  ['نسبت',
#   'به',
#   'هزینه\u200cای',
#   'که',
#   'برای',
#   'اتاق',
#   'پرداخت',
#   'کردیم',
#   'اصلا',
#   'مشابه',
#   'تبلیغات',
#   'شما',
#   'نبود'],
#  ['بسیار', 'ساده', 'و', 'کوچک', 'بود'],
#  ['آینه', 'دراتاق', 'خواب', 'نبود'],
#  ['اتاق', 'مجاور', 'عرب', 'بودند'],
#  ['سکوت', 'را', 'رعایت', 'نمی\u200cکردند'],
#  ['علی',
#   'رغم',
#   'اینکه',
#   'ما',
#   'اتاق',
#   'فصل',
#   'با',
#   'طرحهایی',
#   'که',
#   'در',
#   'سایت',
#   'شما',
#   'دیده\u200cبودیم',
#   'را',
#   'انتخاب',
#   'کردیم',
#   'اتاقی',
#   'که',
#   'به',
#   'ما',
#   'دادند',
#   'یک',
#   'اتاق',
#   'بسیار',
#   'ساده',
#   'و',
#   'در',
#   'طبقات',
#   'پایین',
#   'هتل\u200cبود',
#   'و',
#   'برخورد',
#   'مسوول',
#   'خانم',
#   'رسپشن',
#   'هتل',
#   'اصلا',
#   'درست',
#   'نبود'],
#  ['مجموعه',
#   'اسب\u200cها',
#   'و',
#   'رستوران\u200c\u200cها',
#   'بسیار',
#   'عالی',
#   'بود'],
#  ['من', 'خیلی', 'مشهد', 'می\u200cروم'],
#  ['آخرین',
#   'سفرم',
#   'برای',
#   'من',
#   'رویایی',
#   'شد',
#   'بخاطر',
#   'اقامت',
#   'در',
#   'هتل',
#   'درویشی'],
#  ['در',
#   'بدو',
#   'ورود',
#   'به',
#   'فرودگاه',
#   'مشهد',
#   'با',
#   'برخورد',
#   'بسیار',
#   'محبت\u200cآمیز',
#   'پرسنل',
#   'ترانسفر',
#   'هتل',
#   'مواجه',
#   'شدم'],
#  ['نمی\u200cدانم',
#   'چرا',
#   'از',
#   'همان',
#   'لحظه',
#   'حدس',
#   'زدم',
#   'این',
#   'سفر',
#   'با',
#   'سفرهای',
#   'قبلی',
#   'فرق',
#   'خواهد',
#   'داشت'],
#  ['مسیر', 'فرودگاه', 'تا', 'هتل', 'طول', 'مسیر', 'بسیار', 'اندک', 'بود'],
#  ['وقتی', 'وارد', 'هتل', 'شدم', 'لابی', 'هتل', 'محسورم', 'کرد'],
#  ['وقتی',
#   'برخورد',
#   'پرسنل',
#   'هتل',
#   'را',
#   'دیدم',
#   'متوجه',
#   'شدم',
#   'که',
#   'این',
#   'لابی',
#   'هتل',
#   'نبود',
#   'که',
#   'محسورم',
#   'کرد',
#   'بلکه',
#   'برخورد',
#   'بسیار',
#   'مودبانه',
#   'و',
#   'محبت\u200cآمیز',
#   'پرسنل\u200cبود',
#   'که',
#   'مرا',
#   'تحت',
#   'تاثیر',
#   'قرا',
#   'داده',
#   'است'],
#  ['در', 'کمال', 'احترام', 'پذیرش', 'انجام', 'شد'],
#  ['وقتی',
#   'وارد',
#   'اطاق',
#   'شدم',
#   'باور',
#   'کنید',
#   'همان',
#   'احساسی',
#   'را',
#   'داشتم',
#   'که',
#   'وقتی',
#   'وارد',
#   'خانه',
#   'خودم',
#   'میشوم'],
#  ['راستی',
#   'چون',
#   'پروازم',
#   'صبح',
#   'زود\u200cبود',
#   'سریع',
#   'به',
#   'صبحانه',
#   'رفتم'],
#  ['در', 'مورد', 'صبحانه', 'باید', 'بگویم', 'بی\u200cنظیر', 'بود'],
#  ['از',
#   'نظر',
#   'تمیزی',
#   'و',
#   'زیبایی',
#   'و',
#   'مدرن',
#   'بودن',
#   'بسیار',
#   'عالی',
#   'بود'],
#  ['رستوران\u200cها', 'خوب', 'نبود'],
#  ['دوست', 'دارم', 'حتما', 'به', 'این', 'هتل', 'سفر', 'کنم'],
#  ['هنوز', 'امکان', 'را', 'از', 'لحاظ', 'مالی', 'پیدا', 'نکرده\u200cام'],
#  ['یکروز', 'حتما', 'می\u200cآیم'],
#  ['به', 'امید', 'دیدار'],
#  ['من',
#   'خیلی',
#   'دوست',
#   'دارم',
#   'در',
#   'این',
#   'هتل',
#   'مشغول',
#   'به',
#   'کار',
#   'بشوم',
#   'فکر',
#   'نمی\u200cکنم',
#   'امکانش',
#   'باشد'],
#  ['این',
#   'هتل',
#   'افرادی',
#   'را',
#   'می\u200cخواهد',
#   'با',
#   'سوابق',
#   'کاری',
#   'بالا',
#   'که',
#   'این',
#   'درخواست',
#   'برای',
#   'من',
#   'امکان\u200cپذیر',
#   'نیست'],
#  ['با', 'تشکر'],
#  ['من',
#   'به',
#   'دلیل',
#   'وضعیت',
#   'بد',
#   'مالی',
#   'متاسفانه',
#   'نمی\u200cتوانم',
#   'در',
#   'این',
#   'هتل',
#   'اقامت',
#   'کنم'],
#  ['امکانات',
#   'هتل',
#   'شما',
#   'را',
#   'که',
#   'در',
#   'این',
#   'وبسایت',
#   'دیدم',
#   'آرزو',
#   'می\u200cکنم',
#   'بتوانم',
#   'یک',
#   'هفته',
#   'در',
#   'این',
#   'هتل',
#   'با',
#   'خانواده',
#   'اقامت',
#   'کنم'],
#  ['واقعا', 'خسته', 'نباشید'],
#  ['با', 'سلام'],
#  ['هتل', 'بسیار', 'خوب'],
#  ['با', 'امکانات', 'واقعی', 'یک', 'هتل', '٥', 'ستاره', 'می\u200cباشد'],
#  ['از', 'اقامت', 'خود', 'بسیار', 'راضی', 'بودم'],
#  ['تنها',
#   'ایراد',
#   'هتل',
#   'این',
#   'است',
#   'که',
#   'سیستم',
#   'رزرو',
#   'اینترنتی',
#   'بسیار',
#   'ضعیفی',
#   'دارد'],
#  ['درحال',
#   'حاضر',
#   'یک',
#   'روز',
#   'است',
#   'که',
#   'دارم',
#   'سعی',
#   'می\u200cکنم',
#   'رزرو',
#   'انجام',
#   'دهم',
#   'ولی',
#   'موفق',
#   'نمیشوم'],
#  ['سه', 'شب', 'اقامت', 'در', 'اتاقهای', 'دبل', 'هتل', 'داشتم'],
#  ['هتل', 'بسیار', 'شیک', 'و', 'زیبائی', 'بود'],
#  ['بر',
#   'خلاف',
#   'انتظارم',
#   'ایرادهای',
#   'مهمی',
#   'هم',
#   'دارد',
#   'که',
#   'مدیرت',
#   'محترم',
#   'لازم',
#   'است',
#   'در',
#   'صدد',
#   'رفع',
#   'آن',
#   'برآید'],
#  ['اولین',
#   'چیزی',
#   'که',
#   'از',
#   'هتلی',
#   'در',
#   'این',
#   'سطح',
#   'انتظار',
#   'میرود',
#   'سکوت',
#   'و',
#   'آرامش',
#   'است'],
#  ['به',
#   'دو',
#   'علت',
#   'سکوت',
#   'و',
#   'آرامش',
#   'در',
#   'هتل',
#   'خدشه',
#   'دار\u200cشده\u200cاست'],
#  ['به',
#   'علت',
#   'موقعیت',
#   'رستوران',
#   'اصلی',
#   'هتل',
#   'و',
#   'اشراف',
#   'اتاقهای',
#   'موجود',
#   'تا',
#   'طبقه',
#   'دهم',
#   'به',
#   'آن',
#   'که',
#   'در',
#   'نوع',
#   'خود',
#   'خلاقانه',
#   'و',
#   'زیباست',
#   'متاسفانه',
#   'هر',
#   'شب',
#   'تا',
#   '2',
#   'نیمه',
#   'شب',
#   'صدای',
#   'قاشق',
#   'و',
#   'چنگال',
#   'و',
#   'موسیقی',
#   'رستوران',
#   'در',
#   'تمامی',
#   'اتاقها',
#   'حتی',
#   'در',
#   'طبقه',
#   'دهم',
#   'به',
#   'وضوح',
#   'شنیده',
#   'می\u200cشود'],
#  ['خود', 'بدجوری', 'مخل', 'آرامش', 'هست'],
#  ['متاسفانه',
#   'جنس',
#   'و',
#   'قطر',
#   'دیوارهای',
#   'بین',
#   'اتاقها',
#   'به',
#   'گونه\u200cای',
#   'است',
#   'که',
#   'اگر',
#   'اندکی',
#   'بلند',
#   'صحبت',
#   'کنیم',
#   'یا',
#   'از',
#   'حد',
#   'معمول',
#   'صدای',
#   'تلویزیون',
#   'را',
#   'بلند\u200cتر',
#   'کنیم',
#   'به',
#   'راحتی',
#   'در',
#   'اتاق',
#   'مجاور',
#   'قابل',
#   'شنیدن',
#   'است'],
#  ['این', 'هم', 'خود', 'مخل', 'آرامش', 'می\u200cباشد'],
#  ['بنده',
#   'در',
#   'این',
#   'سه',
#   'شب',
#   'هم',
#   'مجبور',
#   'شدم',
#   'به',
#   'همسایه',
#   'اتاقم',
#   'تذکر',
#   'دهم',
#   'تا',
#   'صدای',
#   'تلویزیون',
#   'را',
#   'کمتر',
#   'کند'],
#  ['مجبور\u200cبودم', 'صدای', 'رستوران', 'را', 'تحمل', 'کنم'],
#  ['جابجائی', 'اتاق', 'به', 'طبقات', 'بالاتر', 'هم', 'میسر', 'نشد'],
#  ['مطمئنا',
#   'مدیریت',
#   'هتل',
#   'با',
#   'اندکی',
#   'تغییر',
#   'می\u200cتواند',
#   'مشکلات',
#   'مذکور',
#   'را',
#   'حل',
#   'کند'],
#  ['دوستان', 'عزیز', 'قبل', 'از', 'هر', 'چیز', 'باید', 'سلام', 'بگویم'],
#  ['صاحب', 'این', 'هتل', 'بسیار', 'انسان', 'والا', 'و', 'متشخصی', 'هستند'],
#  ['تمام', 'تلاششان', 'در', 'جهت', 'رفاه', 'حال', 'مهمان', 'است'],
#  ['بسی', 'جای', 'تشکر', 'دارد'],
#  ['فضای', 'هتل', 'هم', 'در', 'نوع', 'خود', 'جالب', 'و', 'دیدنی', 'است'],
#  ['برخورد', 'پرسنل', 'بسیار', 'مودبانه', 'بود'],
#  ['چند',
#   'نکته',
#   'را',
#   'در',
#   'جهت',
#   'بهتر',
#   'شدن',
#   'کیفیت',
#   'هتل',
#   'باید',
#   'بگویم'],
#  ['اول', 'اینکه', 'قسمت', 'رزرواسیون', 'کمی', 'ضعیف', 'عمل', 'می\u200cکنند'],
#  ['چند',
#   'مورد',
#   'دیدم',
#   'که',
#   'اتاق\u200cها',
#   'اشتباهی',
#   'رزرو\u200cشده\u200cبود'],
#  ['از',
#   'جمله',
#   'اتاق',
#   'خود',
#   'ما',
#   'دوم',
#   'نوع',
#   'پوشش',
#   'پرسنل',
#   'خانم',
#   'بود'],
#  ['نپسندیدم', 'البته', 'بنده', 'با', 'پوشش', 'چادر', 'مخالف', 'نیستم'],
#  ['فکر', 'می\u200cکنم', 'برای', 'خودشان', 'دست', 'و', 'پا', 'گیر', 'بود'],
#  ['همچین',
#   'می\u200cشد',
#   'هتلی',
#   'با',
#   'پوشش',
#   'شیک\u200cتر',
#   'در',
#   'عین',
#   'حال',
#   'اسلامی',
#   'به',
#   'کار',
#   'برود'],
#  ['وقتی',
#   'ایشان',
#   'را',
#   'میبینی',
#   'ناخود',
#   'آگاه',
#   'یاد',
#   'بانوان',
#   'پلیس',
#   'می\u200cافتید'],
#  ['غیر', 'از', 'این', 'موارد', 'همه', 'چه', 'عالیست'],
#  ['از',
#   'ترانسفر',
#   'گرفته',
#   'تا',
#   'اتاق\u200cها',
#   'و',
#   'رستوران\u200cها',
#   'و',
#   'بقیه',
#   'موارد',
#   'در',
#   'کل',
#   'پیشنهاد',
#   'می\u200cکنم',
#   'یکبار',
#   'امتحان',
#   'کنید',
#   'خوش',
#   'می\u200cگذرد'],
#  ['در',
#   'ضمن',
#   'به',
#   'حرم',
#   'امن',
#   'آقا',
#   'هم',
#   'نزدیکه',
#   'من',
#   'هنوز',
#   'اینجا',
#   'هستم',
#   'و',
#   'از',
#   'زیبایی',
#   'آن',
#   'لذت',
#   'دارم',
#   'می\u200cبرم'],
#  ['من', 'از', 'رستوران', 'این', 'هتل', 'دو', 'شبی', 'استفاده', 'کردم'],
#  ['واقعا', 'لذت', 'بردم', 'از', 'پذیرایی', 'پرسنل', 'این', 'هتل'],
#  ['پیشنهاد', 'می\u200cکنم', 'حتما', 'سری', 'به', 'این', 'هتل', 'بزنید'],
#  ['باسلام'],
#  ['من', 'به', 'اتفاق', 'خانواده', 'سفر', 'ده', 'روزه', 'داشتیم', 'به', 'مشهد'],
#  ['تصمیم',
#   'بر',
#   'این',
#   'شد',
#   'مدت',
#   '5',
#   'روز',
#   'در',
#   'هتل',
#   'قصرطلایی',
#   'و',
#   '5',
#   'روز',
#   'در',
#   'هتل',
#   'درویشی',
#   'سپری',
#   'شود'],
#  ['ابتدا',
#   'هتل',
#   'قصر',
#   'طلایی',
#   'از',
#   'لحاظ',
#   'پذیرش',
#   'منوی',
#   'صبحانه',
#   'و',
#   'رستوران\u200cها',
#   'و',
#   'اندازه',
#   'اتاق',
#   'عالی',
#   'بود'],
#  ['اتاق', 'بسیار', 'کوچک'],
#  ['رستوران', 'تاریک', 'وخفه'],
#  ['زمان',
#   'تخلیه',
#   'هم',
#   'برای',
#   'تسویه',
#   'حساب',
#   'بعد',
#   'از',
#   'نیم',
#   'ساعت',
#   'معطلی',
#   'تازه',
#   'یادشان',
#   'آمد',
#   'که',
#   'ما',
#   'منتظر',
#   'تسویه',
#   'حساب',
#   'هستیم'],
#  ['زود\u200cتر', 'از', 'موعد', 'از', 'خدمتشان', 'مرخص', 'شویم'],
#  ['دوباره', 'برگشتیم', 'همان', 'هتل', 'قصر', 'طلایی'],
#  ['در',
#   'شاپینگ',
#   'سن\u200cتر',
#   'یک',
#   'کیلو',
#   'پسته',
#   'خریدم',
#   'برای',
#   'دوستانم',
#   'که',
#   'اگر',
#   'دوست',
#   'داشتند',
#   'چندین',
#   'کیلو',
#   'بخرند'],
#  ['فروشنده',
#   'با',
#   'زیرکی',
#   'خود',
#   'را',
#   'توازن',
#   'نام\u200cگذاری',
#   'کرده',
#   'که',
#   'در',
#   'لاتین',
#   'بسیار',
#   'نزدیک',
#   'به',
#   'برند',
#   'قوی',
#   'و',
#   'با',
#   'آبروی',
#   'ایرانی',
#   'تواضع',
#   'می\u200cباشد'],
#  ['بسیار',
#   'گران',
#   'و',
#   'هم',
#   'کهنه',
#   'و',
#   'درونش',
#   'حشره',
#   'موج',
#   'می\u200cزد'],
#  ['با',
#   'برخورد',
#   'کاملا',
#   'بی\u200cسواد',
#   'صاحب',
#   'فروشگاه',
#   'که',
#   'هر',
#   'دو',
#   'برادر\u200cبودند',
#   'مواجه',
#   'شدیم'],
#  ['نه',
#   'تنها',
#   'نخریدم',
#   'بلکه',
#   'دیگر',
#   'برای',
#   'دوستان',
#   'خارجی\u200cام',
#   'هرگز',
#   'این',
#   'هتل',
#   'را',
#   'رزرو',
#   'نمی\u200cکنم'],
#  ['به', 'هتل', 'آزادی', 'یا', 'اسپیناس', 'نقل', 'مکان', 'کردیم'],
#  ['با', 'سلام'],
#  ['هتل',
#   'پارسیان',
#   'استقال',
#   'یکی',
#   'از',
#   'بهترین',
#   'هتل\u200c\u200cها',
#   'می\u200cباشد'],
#  ['موضوع',
#   'این',
#   'هست',
#   'که',
#   'مدیریت',
#   'و',
#   'عوامل',
#   'این',
#   'هتل',
#   'اصلا',
#   'اقدامی',
#   'برای',
#   'بروز',
#   'کردن',
#   'هتل',
#   'نمی\u200cکنند'],
#  ['من', 'حدود', '8', 'سال', 'پیش', 'هم', 'در', 'این', 'هتل', 'اقامت', 'داشتم'],
#  ['تغییر', 'آنچنانی', 'مشاهده', 'نکردم'],
#  ['تنها', 'چیزی', 'که', 'دراین', 'هشت', 'سال', 'اضافه\u200cشده\u200cبود'],
#  ['عوامل',
#   'و',
#   'مدیریت',
#   'هتل',
#   'تلیویزیون',
#   'هتل',
#   'را',
#   'هم',
#   'عوض',
#   'نکرده',
#   'بودند'],
#  ['حالا', 'ما', 'خودمان', 'هیچ', 'یک\u200cجوری', 'کنار', 'می\u200cآییم'],
#  ['با',
#   'توجه',
#   'به',
#   'اینکه',
#   'این',
#   'هتل',
#   '5',
#   'ستاره',
#   'و',
#   'بین\u200cالمللی',
#   'هست',
#   'و',
#   'مسافران',
#   'زیادی',
#   'هم',
#   'از',
#   'کشور\u200cهای',
#   'دیگر',
#   'می\u200cآیند',
#   'درخور',
#   'یک',
#   'هتل',
#   '5',
#   'ستاره',
#   'نیست'],
#  ['خودم', 'به', 'شخصه', '2', 'ستاره', 'به', 'این', 'هتل', 'می\u200cدهم'],
#  ['انشااله',
#   'که',
#   'در',
#   'اقامت',
#   'بعدی',
#   'شاهد',
#   'تغییرات',
#   'کلی',
#   'در',
#   'این',
#   'هتل',
#   'باشم'],
#  ['سلام',
#   'من',
#   'برای',
#   'مسافرت',
#   'کاری',
#   'سه',
#   'شب',
#   'در',
#   'این',
#   'هتل',
#   'اقامت',
#   'داشتم'],
#  ['در', 'کل', 'راضی', 'بودم'],
#  ['میزان',
#   'آرامشی',
#   'که',
#   'برای',
#   'استراحت',
#   'و',
#   'استحمام',
#   'لازم\u200cبود',
#   'را',
#   'داشت'],
#  ['قدیمی', 'و', 'جدید', 'بودن', 'وسایل', 'برایم', 'تفاوتی', 'نداشت'],
#  ['در', 'کل', 'خوب', 'بود'],
#  ['به',
#   'افرادی',
#   'که',
#   'سفر',
#   'کاری',
#   'می\u200cروند',
#   'پیشنهاد',
#   'می\u200cکنم'],
#  ['اتاق\u200c\u200cهای', 'اصلا', 'درخور', 'هتل', '5', 'ستاره', 'نبود'],
#  ['واقعا', 'وسایل', 'کهنه', 'و', 'قدیمی', 'بودند'],
#  ['شخصا',
#   'ترجیح',
#   'می\u200cدهم',
#   'به',
#   'هتلی',
#   'بروم',
#   'که',
#   'وسایل',
#   'مدرن',
#   'و',
#   'شیک',
#   'باشد'],
#  ['متاسفانه',
#   'هتل',
#   'پارسیان',
#   'استقلال',
#   'اصلا',
#   'در',
#   'حد',
#   'و',
#   'اندازه',
#   'یک',
#   'هتل',
#   '٥',
#   'ستاره',
#   'نیست'],
#  ['دست', 'کم', 'در', 'حال', 'حاضر', 'نیست'],
#  ['اتاق\u200c\u200cهای',
#   'برج',
#   'شرقی',
#   'که',
#   'گویا',
#   'نوسازی',
#   'شده\u200cاند',
#   'اما',
#   'کماکان',
#   'نیاز',
#   'به',
#   'نوسازی',
#   'دارند'],
#  ['یخچال',
#   'داخل',
#   'اتاق',
#   'معلوم',
#   'نبود',
#   'متعلق',
#   'به',
#   'چه',
#   'قرنی',
#   'هست'],
#  ['سرویس',
#   'بهداشتی',
#   'یک',
#   'هتل',
#   'ایرانی',
#   'باید',
#   'شلنگ',
#   'آب',
#   'داشته',
#   'باشد'],
#  ['خشک', 'کن', 'مو', 'در', 'حمام', 'موجود', 'نبود'],
#  ['به',
#   'هیچ',
#   'عنوان',
#   'این',
#   'هتل',
#   'را',
#   'به',
#   'دیگران',
#   'توصیه',
#   'نمی\u200cکنم'],
#  ['حاضر', 'به', 'استفاده', 'دوباره', 'از', 'این', 'هتل', 'نیز', 'نیستم'],
#  ['امیدوارم',
#   'بازخورد',
#   'نطر',
#   'مشتریان',
#   'در',
#   'بهسازی',
#   'هتل',
#   'موثر',
#   'باشد'],
#  ['اتاق\u200c\u200cها',
#   'هیچ',
#   'تغییری',
#   'نسبت',
#   'به',
#   'ده',
#   'سال',
#   'گذشته',
#   'نکرده',
#   'است'],
#  ['تلویزیون\u200c\u200cها',
#   'الان',
#   'در',
#   'دهات',
#   'هم',
#   'استفاده',
#   'نمی\u200cشود'],
#  ['اتاق\u200c\u200cها',
#   'مورد',
#   'تایید',
#   'بنده',
#   'برای',
#   'یک',
#   'هتل',
#   '5',
#   'ستاره',
#   'نیست'],
#  ['ضمنا',
#   'هتلی',
#   '5',
#   'ستاره',
#   'هست',
#   'که',
#   'امکانات',
#   'استخر',
#   'و',
#   'سونا',
#   'و',
#   'جکوزی',
#   'نیز',
#   'داشته',
#   'باشد'],
#  ['متاسفانه',
#   'این',
#   'هتل',
#   'در',
#   'قبال',
#   'مبلغ',
#   'سی',
#   'و',
#   'پنج',
#   'هزار',
#   'تومان',
#   'امکان',
#   'استفاده',
#   'از',
#   'استخر',
#   'را',
#   'می\u200cدهد'],
#  ['با',
#   'توجه',
#   'به',
#   'بین\u200cالمللی',
#   'بودن',
#   'وتعداد',
#   'ستاره',
#   'لوازم',
#   'کهنه',
#   'وموکت\u200cها',
#   'کثیف',
#   'بودند'],
#  ['ازنظرنظافت',
#   'اتاق',
#   'خوب\u200cبود',
#   'تجهیزات',
#   'واثاثیه',
#   'کلا',
#   'کهنه',
#   'و',
#   'قدیمی',
#   'بود'],
#  ['وضعیت',
#   'حمام',
#   'و',
#   'توالت',
#   'فرنگی',
#   'و',
#   'شیرآلات',
#   'بهداشتی',
#   'اصلا',
#   'درحد',
#   'هتل',
#   'سه',
#   'ستاره',
#   'هم',
#   'نبود'],
#  ['نارضایتیم',
#   'را',
#   'نیز',
#   'درموقع',
#   'تسویه',
#   'حساب',
#   'با',
#   'مسئول',
#   'هتل',
#   'اعلام',
#   'کردم'],
#  ['حرفی', 'برای', 'گفتن', 'نداشت'],
#  ['برخورد', 'و', 'رفتار', 'کارکنان', 'هتل', 'عالی'],
#  ['کیفیت', 'غذا', 'و', 'رستوران', 'مطلوب', 'بود'],
#  ['متاسفانه',
#   'کیفیت',
#   'و',
#   'نظافت',
#   'اتاق',
#   'اصلا',
#   'در',
#   'حد',
#   'نام',
#   'این',
#   'هتل',
#   'نبود'],
#  ['مخصوصا', 'سرویس', 'بهداشتی', 'با', 'دوش', 'حمام', 'خراب'],
#  ['با',
#   'تجربیات',
#   'قبلی',
#   'من',
#   'در',
#   'خصوص',
#   'هتل\u200cهای',
#   'پنج',
#   'ستاره',
#   'ایران',
#   'این',
#   'هتل',
#   'نمره',
#   'قبولی',
#   'می\u200cگیرد'],
#  ['ضمن',
#   'عرض',
#   'تبریک',
#   'سال',
#   'جدید',
#   '2',
#   'نکته',
#   'که',
#   'به',
#   'نظر',
#   'اینجانب',
#   'رسید',
#   'به',
#   'استحضار',
#   'می\u200cرسانم'],
#  ['آسانسور',
#   'در',
#   'زمان',
#   'ایستادن',
#   'در',
#   'طبقات',
#   'بخصوص',
#   'هنگام',
#   'بالا',
#   'رفتن',
#   'بنظر',
#   'میرسد',
#   'دارای',
#   'اشکال',
#   'است'],
#  ['اگر',
#   'در',
#   'برنامه',
#   'صبحانه',
#   'هتل',
#   'از',
#   'سوسیس',
#   'و',
#   'کالباس',
#   'کم\u200cشده\u200cو',
#   'از',
#   'گروه\u200cهای',
#   'غذایی',
#   'سبزیجات',
#   'و',
#   'گوشت',
#   'بیشتر',
#   'استفاده',
#   'گردد',
#   'بسیار',
#   'بهتر',
#   'خواهد',
#   'بود'],
#  ['با', 'آرزوی', 'بهروزی', 'برای', 'تمام', 'عزیزان'],
#  ['عید', 'نوروز', 'دو', 'روز', 'در', 'این', 'هتل', 'بودیم'],
#  ['اگر',
#   'از',
#   'قبل',
#   'رزرو',
#   'نمی\u200cکردیم',
#   'همان',
#   'روز',
#   'اول',
#   'برمیگشتیم'],
#  ['اطاق\u200cها',
#   'خیلی',
#   'کوچیک\u200cبود',
#   'و',
#   'همان',
#   'بافت',
#   'قدیمی',
#   'سرویس',
#   'بهداشتی',
#   'و',
#   'حمام',
#   'واقعا',
#   'در',
#   'شان',
#   'هتل',
#   '5',
#   'ستاره',
#   'نبود'],
#  ['به', 'سه', 'ستاره', 'می\u200cخورد'],
#  ['آب', 'حمام', 'سرد', 'بود'],
#  ['مجبور', 'شدیم', 'اطاق', 'را', 'عوض', 'کنیم'],
#  ['وقت', 'صبحانه', 'مهمان\u200cها', 'زیاد', 'بودند'],
#  ['جا',
#   'برای',
#   'نشستن',
#   'نبود',
#   'مجبور',
#   'شدن',
#   'از',
#   'لابی',
#   'استفاده',
#   'کنند'],
#  ['نهارش', 'کیفیت', 'پایین', 'بود'],
#  ['وقتی',
#   'وارد',
#   'شدیم',
#   'فکر',
#   'می\u200cکردم',
#   'حداقل',
#   'کسی',
#   'هست',
#   'جلوی',
#   'در',
#   'چمدان\u200cها',
#   'را',
#   'بگیرد'],
#  ['استقبال',
#   'هتل',
#   'برای',
#   'یک',
#   'هتل',
#   '5',
#   'ستاره',
#   'خیلی',
#   'خیلی',
#   'ضعیف',
#   'بود'],
#  ['روز',
#   'سوم',
#   'با',
#   'این',
#   'که',
#   '5',
#   'روز',
#   'تهران\u200cبودیم',
#   'به',
#   'این',
#   'هتل',
#   'رفتیم',
#   'همان',
#   'یک',
#   'بار',
#   'کافی',
#   'بود'],
#  ['با', 'توجه', 'به', 'قیمتش', 'واقعا', 'ضعیف', 'بود'],
#  ['من', 'یک', 'هفته', 'در', 'هتل', 'استقلال', 'اقامت', 'داشتم'],
#  ['به', 'نظرم', 'در', 'شان', 'یک', 'هتل', '5', 'ستاره', 'نیست'],
#  ['حجاب',
#   'و',
#   'نوع',
#   'پوشش',
#   'خانم\u200c\u200cها',
#   'و',
#   'اقایان',
#   'و',
#   'طرز',
#   'رفتار',
#   'افراد',
#   'را',
#   'ایراد',
#   'نگیرند',
#   'بهتر',
#   'است'],
#  ['مهم\u200cترین',
#   'مزیت',
#   'این',
#   'هتل',
#   'نزدیکی',
#   'به',
#   'مرکز',
#   'خرید',
#   'لاله',
#   'پارک',
#   'هست'],
#  ['موقعیت', 'مکانی', 'به', 'دور', 'از', 'شلوغی', 'شهر', 'است'],
#  ['انتظار',
#   'استفاده',
#   'از',
#   'هتل\u200c\u200cهای',
#   'هما',
#   'در',
#   'گذشته',
#   'را',
#   'نداشته',
#   'باشید'],
#  ['برخورد', 'کارکنان', 'و', 'پذیرش', 'بسیار', 'عالی', 'است'],
#  ['خدمات',
#   'خانه\u200cداری',
#   'متوسط',
#   'و',
#   'در',
#   'بخش',
#   'رستوران',
#   'ضعیف',
#   'می\u200cباشد'],
#  ['هزینه',
#   'غذا',
#   'بخصوص',
#   'در',
#   'بخش',
#   'ویلائی',
#   'آن',
#   'چند',
#   'برابر',
#   'معمول',
#   'محاسبه',
#   'می\u200cگردد'],
#  ['در', 'کل', 'هتل', 'تمیزی', 'بود'],
#  ['به', 'نسبت', 'قیمت', 'با', 'سایر', 'هتل\u200c\u200cها', 'مناسب', 'بود'],
#  ['نزدیک', 'بودن', 'هتل', 'به', 'دریا', 'نیز', 'از', 'مزایای', 'آن', 'است'],
#  ['یک', 'هتل', 'خوب', 'با', 'قیمت', 'مناسب'],
#  ['در',
#   'بهترین',
#   'نقطه',
#   'تهران',
#   'از',
#   'لحاظ',
#   'نزدیکی',
#   'به',
#   'مراکز',
#   'اداری'],
#  ['ایراد', 'خاصی', 'در', 'این', 'هتل', 'ندیدم'],
#  ['همه', 'چیز', 'نسبتا', 'خوب', 'بود'],
#  ['برای',
#   'اولین',
#   'بار',
#   'سامانه',
#   'رزرواسیون',
#   'مهر',
#   'رزرو',
#   'کرده',
#   'بودم'],
#  ['اتاق', 'سوییت', 'ویژه\u200cبود', 'و', 'بهترین', 'اتاق', 'هتل'],
#  ['نمی\u200cدانم',
#   'شاید',
#   'چون',
#   'ما',
#   'سوییت',
#   'ویژه',
#   'داشتیم',
#   'همه',
#   'چی',
#   'خوب',
#   'بود'],
#  ['متاسفانه',
#   'علی',
#   'رغم',
#   'پنج',
#   'ستاره',
#   'بودن',
#   'این',
#   'هتل',
#   'اصلا',
#   'نباید',
#   'شکل',
#   'اتاق\u200cها',
#   'این\u200cگونه',
#   'قدیمی',
#   'باشد'],
#  ['خواهشمندم',
#   'درانتخاب',
#   'رنگ',
#   'موکت',
#   'و',
#   'پرده\u200c\u200cها',
#   'از',
#   'رنگ\u200cهای',
#   'بهتری',
#   'استفاده',
#   'نمایید'],
#  ['تختها', 'دیگر', 'عمرشان', 'به', 'پایان', 'رسیده', 'باید', 'تعویض', 'شوند'],
#  ['باتشکر'],
#  ['به',
#   'خاطر',
#   'برخورد',
#   'خوب',
#   'کارمندان',
#   'ازهتل',
#   'هما',
#   '2',
#   'رضایت',
#   'خاطر',
#   'دارم'],
#  ['کیفیت',
#   'اطاقهای',
#   'هتل',
#   'اصلا',
#   'در',
#   'حد',
#   'یک',
#   'هتل',
#   'پنج',
#   'ستاره',
#   'نبود'],
#  ['با',
#   'تشکر',
#   'دوباره',
#   'از',
#   'مدیریت',
#   'هتل',
#   'به',
#   'جهت',
#   'مساعدتشان',
#   'و',
#   'تعویض',
#   'اطاق',
#   '401',
#   'به',
#   'دلیل',
#   'کیفیت',
#   'پایینش',
#   'با',
#   'اطاق\u200cهای',
#   'بازسازی\u200cشده',
#   '407',
#   'و',
#   '408'],
#  ['همه', 'چه', 'خوب', 'و', 'عالی', 'بود'],
#  ['خرداد', '97', 'سه', 'روز', 'آنجا', 'بودم'],
#  ['وان', 'حمام', 'نداشت', 'باز', 'هم', 'عالی', 'بود'],
#  ['سلام', 'خدمت', 'عزیزان'],
#  ['من', 'و', 'همسرم', 'دیروز', 'از', 'کیش', 'برگشتیم'],
#  ['حدود', '13', 'یا', '14', 'بار', 'کیش', 'آمدیم'],
#  ['هر', 'بار', 'هتل\u200cهای', '5', 'ستاره', 'و', 'خوب', 'را', 'رفتیم'],
#  ['این',
#   'هتل',
#   'به',
#   'نظرم',
#   'بسیار',
#   'بسیار',
#   'خوب',
#   'و',
#   'همه',
#   'چی',
#   'در',
#   'حد',
#   'عالی',
#   'بود'],
#  ['رفتار', 'پرسنل', 'بسیار', 'مودب', 'و', 'با', 'محبت'],
#  ['تمیزی', 'و', 'سرویس\u200cدهی', 'عالی'],
#  ['کیفیت', 'رستوران', 'و', 'صبحانه', 'بسیار', 'عالی', 'و', 'خوشمزه'],
#  ['انتخاب', 'خیلی', 'خوبی', 'هست'],
#  ['مخصوصا', 'که', 'نوساز', 'هست'],
#  ['تمام', 'وسایل', 'نو', 'و', 'شیک'],
#  ['من', 'دیروز', 'از', 'اقامت', 'این', 'هتل', 'برگشتم'],
#  ['آن',
#   'قدر',
#   'همه',
#   'چه',
#   'عالی\u200cبود',
#   'که',
#   'من',
#   'سختگیر',
#   'و',
#   'سخت\u200cپسند',
#   'را',
#   'متقاعد',
#   'کرد'],
#  ['تا', 'اینجا', 'نظرم', 'را', 'اعلام', 'کنم'],
#  ['این', 'هتل', 'رویایی', 'بود'],
#  ['من',
#   'تا',
#   'روز',
#   'آخر',
#   'دنبال',
#   'این',
#   'می\u200cگشتم',
#   'یک',
#   'ایرادی',
#   'درکارشان',
#   'پیدا',
#   'کنم'],
#  ['همه', 'چه', 'فوق\u200cالعاده', 'بود'],
#  ['رفتار',
#   'کارکنان',
#   'تمیزی',
#   'هتل',
#   'فضای',
#   'داخل',
#   'اتاق\u200cها',
#   'کیفیت',
#   'صبحانه',
#   'همه',
#   'و',
#   'همه',
#   'عالی',
#   'بودند'],
#  ['برای', 'ما', 'تمیزی', 'و', 'کیفیت', 'غذا', 'خیلی', 'مهم', 'بود'],
#  ['این', 'هتل', 'عالی', 'بود'],
#  ['از', 'هر', 'نظر', 'دستتان', 'درد', 'نکند'],
#  ['کیفیتتان', 'را', 'حفظ', 'کنید', 'لطفا'],
#  ['متاسفانه', 'مبلمان', 'داخل', 'سایت\u200cها', 'را', 'جمع', 'کرده', 'بودند'],
#  ['متاسفانه', 'وان', 'داخل', 'حمام', 'نبود'],
#  ['دوش', 'ساده', 'بود'],
#  ['تختهای',
#   'اضافه',
#   'داخل',
#   'سایت',
#   'بسیار',
#   'فرسوده',
#   'و',
#   'غیر',
#   'استاندارد',
#   'بودند'],
#  ['من',
#   'و',
#   'خانمم',
#   'برای',
#   'ماه',
#   'عسل',
#   'به',
#   'هتل',
#   'شما',
#   'آمدیم',
#   'هتل',
#   'خوبی',
#   'بود'],
#  ['همه', 'چیزش', 'احساس', 'میکنم', 'منظم', 'و', 'اصولی', 'بود'],
#  ['نسبت',
#   'به',
#   'هتل\u200c\u200cهای',
#   'قبلی',
#   'که',
#   'رفته\u200cبودم',
#   'این',
#   'از',
#   'همه',
#   'بهتر',
#   'بود'],
#  ['سلام', 'آقای', 'محسن', 'علی', 'پور', 'عزیز'],
#  ['تلویزیون\u200c\u200cهای',
#   'هتل',
#   'دارای',
#   'گارانتی',
#   'شرکت',
#   'گلد',
#   'ایران',
#   'هستند'],
#  ['اگر',
#   'کسی',
#   'غیر',
#   'از',
#   'کارشناسان',
#   'شرکت',
#   'گلد',
#   'ایران',
#   'دستگاه',
#   'را',
#   'باز',
#   'کنند',
#   'از',
#   'گارانتی',
#   'خارج',
#   'می\u200cشود'],
#  ['در', 'صورت', 'خرابی', 'پاسخگو', 'نیستند'],
#  ['ممنون',
#   'از',
#   'لطف',
#   'شما',
#   'به',
#   'هتل',
#   'و',
#   'به',
#   'امید',
#   'دیدار',
#   'مجدد',
#   'شما'],
#  ['با', 'سلام'],
#  ['همراه',
#   'همسر',
#   'و',
#   'فرزندم',
#   'سه',
#   'روز',
#   'در',
#   'این',
#   'هتل',
#   'اقامت',
#   'داشتیم'],
#  ['متاسفانه', 'در', 'اثر', 'اتفاق', 'صفحه', 'تلویزیون', 'اتاق', 'شکست'],
#  ['خودمان',
#   'اعلام',
#   'کردیم',
#   'که',
#   'خسارت',
#   'جبران',
#   'می\u200cکنیم',
#   'اما',
#   'برخورد\u200c\u200cهای',
#   'بسیار',
#   'بدی',
#   'از',
#   'مدیریت',
#   'هتل',
#   'و',
#   'عوامل',
#   'زیر',
#   'مجموعه',
#   'شاهد',
#   'بودیم'],
#  ['قیمت',
#   'تلویوزیون',
#   'که',
#   'در',
#   'جزیره',
#   'هم',
#   'موجود',
#   'نبود',
#   'به',
#   'زور',
#   'از',
#   'ما',
#   '2',
#   '،',
#   '5',
#   'گرفتند',
#   'قول',
#   'دادند',
#   'اگر',
#   'درست',
#   'شد',
#   'تلویزیون',
#   'را',
#   'از',
#   'ما',
#   'قبول',
#   'کنند',
#   'که',
#   'ظرف',
#   'دو',
#   'ساعت',
#   'پنل',
#   'نو',
#   'گذاشتیم'],
#  ['جواب',
#   'ما',
#   'را',
#   'ندادند',
#   'حتی',
#   'نذاشتند',
#   'با',
#   'مدیریت',
#   'صحبت',
#   'کنیم'],
#  ['پول', 'را', 'از', 'ما', 'گرفته', 'بودند'],
#  ['هتل', 'خوبی', 'هست'],
#  ['افراد',
#   'بی\u200cتجربه',
#   'و',
#   'بی\u200cصداقتی',
#   'آنجا',
#   'را',
#   'اداره',
#   'می\u200cکنند'],
#  ['سلام'],
#  ['تمام',
#   'هتل\u200c\u200cهای',
#   'پنج',
#   'ستاره',
#   'کیش',
#   'را',
#   'رفتم',
#   'بهترین',
#   'هتل',
#   'کیش',
#   'هست'],
#  ['شیک',
#   'خوش',
#   'مسیر',
#   'فول',
#   'امکانات',
#   'و',
#   'برخورد',
#   'و',
#   'سرویس\u200cدهی',
#   'پرسنل',
#   'بی\u200cنظیر',
#   'من',
#   'بالا\u200cترین',
#   'امتیاز',
#   'را',
#   'به',
#   'آن',
#   'می\u200cدهم'],
#  ['صبحانه',
#   'فوق\u200cالعاده',
#   'است',
#   'و',
#   'هرچیزی',
#   'که',
#   'فکر',
#   'شو',
#   'بکنید',
#   'دارد',
#   'و',
#   'کامل',
#   'هست',
#   'حتما',
#   'امتحانش',
#   'کنید'],
#  ['عالی', 'هست'],
#  ['همه', 'چیز', 'عالی', 'و', 'دربالاترین', 'سطح', 'خودش', 'بو', 'د'],
#  ['توصیه',
#   'می\u200cکنم',
#   'اگر',
#   'انتخاب',
#   'هتلی',
#   'آرام',
#   'و',
#   'تمیز',
#   'را',
#   'برای',
#   'سفر',
#   'در',
#   'کیش',
#   'قصد',
#   'دارید',
#   'این',
#   'هتل',
#   'بسیار',
#   'مناسب',
#   'هست'],
#  ['ما', 'در', 'اتاق', '337', 'بودیم'],
#  ['برخورد', 'کارکنان', 'خیلی', 'خوب', 'بود'],
#  ['از', 'لحاظ', 'تمیزی', 'قابل', 'قبول', 'بود'],
#  ['به',
#   'کسانی',
#   'که',
#   'می\u200cخواهند',
#   'به',
#   'این',
#   'هتل',
#   'بروند',
#   'جدی',
#   'توصیه',
#   'می\u200cکنم',
#   'که',
#   'مواظب',
#   'وسایل',
#   'گران',
#   'قیمت',
#   'خود',
#   'باشند'],
#  ['ساعت',
#   'فسیل',
#   'من',
#   'جا',
#   'ماند',
#   'از',
#   '2',
#   'ساعت',
#   'بعد',
#   'از',
#   'تخلیه',
#   'اتاق',
#   'تماس',
#   'گرفتم',
#   'تا',
#   'یک',
#   'هفته',
#   'بعد',
#   'متاسفانه',
#   'هیچ',
#   'کس',
#   'جواب',
#   'گو',
#   'نبود'],
#  ['حتی', 'یکبارهم', 'نتوانستم', 'با', 'مدیریت', 'صحبت', 'کنم'],
#  ['خیلی', 'مراقب', 'وسایل', 'خودتان', 'داخل', 'این', 'هتل', 'باشید'],
#  ['ما', 'در', 'اتاق', '337', 'بودیم'],
#  ['برخورد', 'کارکنان', 'خیلی', 'خوب', 'بود'],
#  ['از', 'لحاظ', 'تمیزی', 'قابل', 'قبول', 'بود'],
#  ['به',
#   'کسانی',
#   'که',
#   'می\u200cخواهند',
#   'به',
#   'این',
#   'هتل',
#   'بروند',
#   'جدی',
#   'توصیه',
#   'می\u200cکنم',
#   'که',
#   'مواظب',
#   'وسایل',
#   'گران',
#   'قیمت',
#   'خود',
#   'باشند'],
#  ['ساعت',
#   'فسیل',
#   'من',
#   'جا',
#   'ماند',
#   'از',
#   '2',
#   'ساعت',
#   'بعد',
#   'از',
#   'تخلیه',
#   'اتاق',
#   'تماس',
#   'گرفتم',
#   'تا',
#   'یک',
#   'هفته',
#   'بعد',
#   'متاسفانه',
#   'هیچ',
#   'کس',
#   'جواب',
#   'گو',
#   'نبود'],
#  ['حتی', 'یکبارهم', 'نتوانستم', 'با', 'مدیریت', 'صحبت', 'کنم'],
#  ['خیلی', 'مراقب', 'وسایل', 'خودتان', 'داخل', 'این', 'هتل', 'باشید'],
#  ['با', 'سلام'],
#  ['نظرات', 'دوستان', 'کاملا', 'صحیح', 'هست'],
#  ['چیز',
#   'دیگری',
#   'که',
#   'من',
#   'را',
#   'بسیار',
#   'اذیت',
#   'کرد',
#   'بوی',
#   'بسیار',
#   'بد',
#   'راهرو',
#   'بود'],
#  ['اتاق', 'من', 'و', 'همسرم', 'ته', 'راهرو', 'طبقه', 'دو', 'بود'],
#  ['انگار', '20', 'ساله', 'که', 'موکت', 'نم', 'گرفته', 'راهرو', 'را', 'نشستند'],
#  ['هتل', 'از', 'نظر', 'موقیعت', 'مکانی', 'عالی', 'است'],
#  ['سرویس', 'بهداشتی', 'شیر', 'آلات', 'کدر', 'و', 'جرم', 'گرفته'],
#  ['پرده', 'سفید', 'آویزان', 'در', 'حمام', 'کثیف', 'متمایل', 'به', 'زرد'],
#  ['حوله\u200c\u200cهای',
#   'حمام',
#   'کدر',
#   'و',
#   'این',
#   'قدر',
#   'در',
#   'مایع',
#   'ضد',
#   'عفونی',
#   'قرار',
#   'گرفته',
#   'است',
#   'با',
#   'نزدیک',
#   'کردن',
#   'به',
#   'صورت',
#   'می\u200cتوانید',
#   'خود',
#   'را',
#   'در',
#   'بیمارستان',
#   'تصور',
#   'کنید'],
#  ['مبلمان', 'اتاق', 'فرسوده', 'و', 'کثیف'],
#  ['تختها',
#   'در',
#   'حقیت',
#   'دوشک',
#   'دوبل',
#   'است',
#   'و',
#   'چیزی',
#   'به',
#   'نام',
#   'تخت',
#   'وجود',
#   'ندارد'],
#  ['این',
#   'موارد',
#   'در',
#   'مورد',
#   'اتاق',
#   'سوییت',
#   'هتل',
#   'جدید',
#   'می\u200cباشد'],
#  ['صبحانه', 'بسیار', 'محدود'],
#  ['همه', 'این', 'موارد', 'را', 'به', 'مدیر', 'هتل', 'هم', 'گفتم'],
#  ['به',
#   'بهانه',
#   'بازسازی',
#   'هتل',
#   'در',
#   'آینده',
#   'نزدیک',
#   'خود',
#   'را',
#   'مقصر',
#   'نمی\u200cدانست'],
#  ['لااقل',
#   'نظافت',
#   'حتی',
#   'در',
#   'مورد',
#   'مسافرخانه',
#   'هم',
#   'قابل',
#   'اجرا',
#   'است'],
#  ['سلام'],
#  ['هتل', 'از', 'نظر', 'دید', 'بسیار', 'عالی', 'هست'],
#  ['خدمه',
#   'با',
#   'ادب',
#   'ولیکن',
#   'افسوس',
#   'که',
#   'ظاهرا',
#   'از',
#   'هتل',
#   'کار',
#   'کشیدن',
#   'و',
#   'کم\u200cتر',
#   'خرج',
#   'کردند'],
#  ['من', 'که', 'درتیرماه', 'رفتم', 'داخل', 'اطاق', 'جک', 'و', 'جانور', 'بود'],
#  ['طبق',
#   'گفته',
#   'مسئولین',
#   'باید',
#   'آخر',
#   'خرداد',
#   'سمپاشی',
#   'می\u200cکردند',
#   'که',
#   'نکرده',
#   'بودند'],
#  ['متاسفانه', 'در', 'رستوران', 'هم', 'یک', 'نوبت', 'سوسک', 'مشاهده', 'شد'],
#  ['بهر', 'حال', 'هتل', 'خوبی', 'هست'],
#  ['قبلش', 'تماس', 'بگیرید', 'که', 'سم\u200cپاشی', 'کردند', 'یا', 'خیر'],
#  ['اتاق', 'ما', 'در', 'طبقه', 'سوم', 'بود'],
#  ['ظاهرا', 'از', 'دو', 'طبقه', 'دیگر', 'بهتر', 'می\u200cباشد'],
#  ['به',
#   'گفته',
#   'مسئول',
#   'پذیرش',
#   'ما',
#   'در',
#   'فصل',
#   'خلوت',
#   'سال',
#   'به',
#   'هتل',
#   'رفتیم',
#   'که',
#   'فرصت',
#   'بیشتری',
#   'جهت',
#   'رسیدن',
#   'به',
#   'شرایط',
#   'اسفبار',
#   'هتل',
#   'و',
#   'خدمات\u200cدهی',
#   'به',
#   'مهمانان',
#   'داشتند'],
#  ['کف', 'اطاق\u200c\u200cها', 'تمیز', 'نبود'],
#  ['دیوار\u200c\u200cها',
#   'کمی',
#   'نم',
#   'داشت',
#   'و',
#   'دیوارپوش',
#   'سالم',
#   'و',
#   'تمیز'],
#  ['سرویس', 'بهداشتی', 'کهنه\u200cشده'],
#  ['تلویزیون', 'خراب', 'مینی', 'بار', 'با', 'کیفیت', 'پایین', 'و', 'گران'],
#  ['شکلات',
#   'آب\u200cمعدنی',
#   'یک',
#   'بسته',
#   'کوچک',
#   'پسته',
#   'یک',
#   'نوشابه',
#   'کوچک',
#   'و',
#   'یک',
#   'دلستر',
#   'قوطی',
#   '45000',
#   'تومان'],
#  ['جالب',
#   'اینکه',
#   'چندین',
#   'بار',
#   'به',
#   'مسئولان',
#   'پذیرش',
#   'اعلام',
#   'نمودیم',
#   'که',
#   'از',
#   'اطاق',
#   'راضی',
#   'نیستیم',
#   'و',
#   'آن',
#   'را',
#   'عوض',
#   'کنید',
#   'در',
#   'این',
#   '3',
#   'روز',
#   'هیچ',
#   'اقدامی',
#   'نکردند',
#   'با',
#   'اینکه',
#   'اکثر',
#   'اطاق\u200c\u200cها',
#   'خالی',
#   'بود'],
#  ['با', 'سلام', 'و', 'تشکراز', 'خدمات', 'شما'],
#  ['سرویس', 'توالت', 'در', 'جای', 'نامناسبی', 'قرار', 'دارد'],
#  ['بدلیل', 'محدودیت', 'جا', 'به', 'دشواری', 'قابل', 'استفاده', 'می\u200cباشد'],
#  ['از',
#   'نظر',
#   'نظافت',
#   'و',
#   'پاکیزگی',
#   'خوب',
#   'و',
#   'از',
#   'نظر',
#   'برخورد',
#   'کارمندان',
#   'عالی',
#   'است'],
#  ['همه', 'چیز', 'عالی'],
#  ['بسیار', 'مکان', 'آرام', 'و', 'دلپذیری', 'بود'],
#  ['در',
#   'طول',
#   'مدت',
#   'اقامتمان',
#   'به',
#   'همراه',
#   'همسرم',
#   'بسیار',
#   'سفر',
#   'خوشی',
#   'را',
#   'تجربه',
#   'کردیم'],
#  ['فضای', 'هتل', 'بسیار', 'آرام', 'و', 'پرسنل', 'مودب', 'بودند'],
#  ['اتاق',
#   'رو',
#   'به',
#   'دریا',
#   'داشتیم',
#   'که',
#   'با',
#   'توجه',
#   'به',
#   'کم',
#   'بودن',
#   'ارتفاع',
#   'هتل',
#   'کلا',
#   'یک',
#   'طبقه',
#   'بالای',
#   'همکف',
#   'دارد'],
#  ['فرقی', 'ندارد', 'و', 'منظره', 'خاصی', 'از', 'دریا', 'نداشتیم'],
#  ['بوفه',
#   'صبحانه',
#   'و',
#   'ناهار',
#   'کاملا',
#   'قابل',
#   'قبول',
#   'و',
#   'استخرش',
#   'بسیار',
#   'خلوت',
#   'و',
#   'تمیز'],
#  ['همه', 'چیز', 'عالی', 'بود'],
#  ['به',
#   'جز',
#   'اینکه',
#   'از',
#   'سرویس',
#   'و',
#   'حمامش',
#   'بیشتری',
#   'انتظار',
#   'می\u200cرفت',
#   'و',
#   'کف',
#   'حمام',
#   'جمع',
#   'آب',
#   'می\u200cشد'],
#  ['سلام',
#   'من',
#   'ودوستم',
#   '4',
#   'تا',
#   '8',
#   'آذر',
#   'در',
#   'هتل',
#   'ماریا',
#   'کیش',
#   'اقامت',
#   'داشتیم'],
#  ['از',
#   'کلیه',
#   'امکانات',
#   'پذیرائی',
#   'نهار',
#   'وصبحانه',
#   'استخر',
#   'برخورد',
#   'پرسنل',
#   'راضی',
#   'هستیم'],
#  ['معماری', 'هتل', 'و', 'پارک', 'آن', 'خیلی', 'خوب', 'بود'],
#  ['درلابی', 'هتل', 'پیانو', 'می\u200cنواختند', 'و', 'فضای', 'عالی', 'داشت'],
#  ['غذا\u200cها', 'متنوع', 'وتمییز', 'وخوب', 'بودند'],
#  ['از',
#   'پیست',
#   'دوچرخه\u200cسواری',
#   'وساحل',
#   'اختصاصی',
#   'هتل',
#   'استفاده',
#   'کردیم'],
#  ['سرویس\u200cهای', 'بهداشتی', 'به', 'روز', 'و', 'تمییز', 'بودند'],
#  ['فضای', 'هتل', 'آرام', 'و', 'باصفا', 'بود'],
#  ['رستوران', 'هتل', 'رو', 'به', 'دریابود'],
#  ['این',
#   'هتل',
#   'را',
#   'به',
#   'همه',
#   'کسانیکه',
#   'می\u200cخواهند',
#   'تعطیلات',
#   'خوبی',
#   'در',
#   'کیش',
#   'بگذرانند',
#   'توصیه',
#   'می\u200cکنم'],
#  ['بسیار', 'عالی', 'و', 'آرامش', 'بخش'],
#  ['سالن',
#   'نمایش',
#   'هتل',
#   'هم',
#   'میزبان',
#   'برنامه',
#   'شبانگاهی',
#   'بسیار',
#   'عالی',
#   'بود'],
#  ['موقعیت', 'مکانی', 'خوب', 'هتل'],
#  ['ساختمان', 'مناسب'],
#  ['متاسفانه',
#   'کارکنان',
#   'هتل',
#   'و',
#   'برخورد',
#   'نامناسب',
#   'آنان',
#   'بسیار',
#   'موجب',
#   'ناراحتی',
#   'ما',
#   'در',
#   'طول',
#   'اقامت',
#   'در',
#   'این',
#   'هتل',
#   'شدند'],
#  ['اطاق', 'با', '5', 'ساعت', 'تاخیر', 'به', 'ما', 'تحویل', 'داده', 'شد'],
#  ['دسترسی', 'مستقیم', 'به', 'ساحل'],
#  ['معماری',
#   'و',
#   'طراحی',
#   'متفاوت',
#   'ویژگی',
#   'منحصر',
#   'به',
#   'فردی',
#   'به',
#   'هتل',
#   'ماریا\u200cها',
#   'داده',
#   'است'],
#  ['پرسنل',
#   'هتل',
#   'آموزش',
#   'ندیده\u200cاند',
#   'و',
#   'تقریبا',
#   'مهارت',
#   'علمی',
#   'و',
#   'حرفه\u200cای',
#   'در',
#   'این',
#   'زمینه',
#   'ندارند'],
#  ['پذیرش', 'قلب', 'هتل', 'است'],
#  ['اولین',
#   'قضاوت',
#   'و',
#   'آخرین',
#   'خاطره',
#   'مسافر',
#   'بر',
#   'اساس',
#   'کیفیت',
#   'کار',
#   'در',
#   'پذیرش',
#   'شکل',
#   'می\u200cگیرد'],
#  ['بی\u200cمسئولیتی',
#   'و',
#   'عدم',
#   'آشنایی',
#   'به',
#   'حساسیت',
#   'و',
#   'ظرافت',
#   'کار',
#   'درمیان',
#   'پرسنل',
#   'پذیرش',
#   'هتل',
#   'ماریا',
#   'تردید\u200c\u200cهای',
#   'جدی',
#   'در',
#   'ذهن',
#   'مسافر',
#   'نسبت',
#   'به',
#   'هتل',
#   'ایجاد',
#   'می\u200cکند'],
#  ['به',
#   'نظر',
#   'اینجانب',
#   'استفاده',
#   'از',
#   'پرسنل',
#   'آموزش',
#   'دیده',
#   'و',
#   'آشنا',
#   'به',
#   'الزامات',
#   'صنعت',
#   'گردشگری',
#   'مهم\u200cترین',
#   'ضرورتی',
#   'است',
#   'که',
#   'مدیریت',
#   'هتل',
#   'باید',
#   'به',
#   'آن',
#   'توجه',
#   'نماید'],
#  ['همه', 'چیز', 'عالی', 'بود'],
#  ['تمیز', 'زیبا'],
#  ['آرام'],
#  ['تنها',
#   'عیبی',
#   'که',
#   'داشت',
#   'این\u200cبود',
#   'که',
#   'شیب',
#   'کف',
#   'حمام',
#   'خیلی',
#   'کم\u200cبود',
#   'و',
#   'آب',
#   'داخل',
#   'حمام',
#   'می\u200cماند',
#   'و',
#   'خشک',
#   'نمی\u200cشد'],
#  ['در', 'کل', 'در', 'آنجا', 'خیلی', 'به', 'ما', 'خوش', 'گذشت'],
#  ['بعد',
#   'از',
#   'هزاران',
#   'بار',
#   'سفر',
#   'به',
#   'کیش',
#   'و',
#   'امتحان',
#   'کردن',
#   'هتل\u200c\u200cهای',
#   'مختلف',
#   'آخرین',
#   'بار',
#   'متاسفانه',
#   'این',
#   'هتل',
#   'را',
#   'انتخاب',
#   'کردم'],
#  ['از',
#   'لحاظ',
#   'قیمت',
#   'حتی',
#   'از',
#   'پارمیس',
#   'و',
#   'داریوش',
#   'هم',
#   'گران\u200cتر',
#   'بود'],
#  ['کیفیت',
#   'هتل\u200c\u200cهای',
#   'ایران',
#   'و',
#   'سیمرغ',
#   'که',
#   'در',
#   'یک',
#   'قدمی',
#   'این',
#   'هتل',
#   'قرار',
#   'داشت',
#   'خیلی',
#   'بهتر',
#   'بود'],
#  ['برخورد',
#   'بسیار',
#   'بسیار',
#   'افتضاح',
#   'کارمندان',
#   'هتل',
#   'درحد',
#   'خود',
#   'بینظیر',
#   'بود'],
#  ['کاش',
#   'مدیریت',
#   'هتل',
#   'کمی',
#   'نظارت',
#   'بر',
#   'اوضاع',
#   'و',
#   'احوال',
#   'این',
#   'هتل',
#   'و',
#   'کارمندان',
#   'آن',
#   'داشت'],
#  ['میهمان', 'به', 'روی', 'گشاده', 'میزبان', 'میرود'],
#  ['زود\u200cتر',
#   'از',
#   'ساعت',
#   '3',
#   'بعدازظهر',
#   'اتاق',
#   'به',
#   'هیچ',
#   'عنوان',
#   'تحویل',
#   'داده',
#   'نمی\u200cشود'],
#  ['اگر',
#   'نفر',
#   'اضافی',
#   'و',
#   'تخت',
#   'اضافی',
#   'بخواهید',
#   'به',
#   'هیچ',
#   'عنوان',
#   'زود\u200cتر',
#   'از',
#   '8',
#   'شب',
#   'تحویل',
#   'نمی\u200cدهند',
#   'حتی',
#   'اگر',
#   'در',
#   'بد\u200cترین',
#   'شرایط',
#   'جسمی',
#   'باشید'],
#  ['یک', 'هتل', 'تمیز', 'می\u200cباشد', 'فعلا', 'همین', 'و', 'بس'],
#  ['واقعا', 'عالی', 'هست'],
#  ['انگار', 'اصلا', 'ایران', 'نیستی'],
#  ['پرسنل', 'مودب'],
#  ['غذا', 'خوب'],
#  ['محیط', 'بسیار', 'زیبا', 'و', 'تمیز'],
#  ['مقداری', 'گران\u200c\u200cتر', 'از', 'هتل', 'داریوش', 'بود'],
#  ['اتاق\u200cها', 'و', 'سرویس', 'آن', 'برتری', 'محسوسی', 'داشت'],
#  ['برخورد', 'کارمندان', 'پذیرش', 'عالی', 'بود'],
#  ['ما', 'آن', 'لاین', 'رزرو', 'کرده', 'بودیم'],
#  ['بعد',
#   'از',
#   'پی\u200cگیری',
#   'ما',
#   'را',
#   'به',
#   'اتاق',
#   'بسیار',
#   'بزرگی',
#   'در',
#   'طبقه',
#   'همکف',
#   'راهنمایی',
#   'کردند',
#   'که',
#   'بسیار',
#   'راحت',
#   'بود'],
#  ['بوفه', 'صبحانه', 'و', 'نهار', 'در', 'حد', 'مبلغ', 'پرداختی', 'ما', 'بود'],
#  ['در',
#   'ضمن',
#   'سانس',
#   'خانوادگی',
#   'استخر',
#   'سرپوشیده',
#   'هم',
#   'استفاده',
#   'کردیم',
#   'که',
#   'یکی',
#   'از',
#   'بهترین',
#   'خاطرات',
#   'سفرمان',
#   'شد'],
#  ['خارق', 'العاده'],
#  ['هتل', 'ساحلی', 'بسیار', 'زیبا', 'با', 'فضای', 'کاملا', 'آرام', 'است'],
#  ['کارمندان', 'آن', 'خوش', 'اخلاق', 'می\u200cباشند'],
#  ['اتاق', 'رزروی', 'ما', 'اتاق', '2', 'نفره', 'رو', 'به', 'دریا', 'بود'],
#  ['شب',
#   'اول',
#   'اتاق',
#   'را',
#   'به',
#   'پارک',
#   'تحویل',
#   'دادند',
#   'و',
#   'گفتند',
#   'به',
#   'علت',
#   'مشکل',
#   'خرابی',
#   'تهویه',
#   'است'],
#  ['پیگیر',
#   'شدیم',
#   'که',
#   'مسافر',
#   'در',
#   'اتاق',
#   'رزروی',
#   'ما',
#   'بوده',
#   'و',
#   'در',
#   'ضمن',
#   'ما',
#   'به',
#   'التفاوت',
#   'مبلغ',
#   'این',
#   'اتاق\u200c\u200cها',
#   'را',
#   'به',
#   'برنگرداندند'],
#  ['عالی'],
#  ['عالی'],
#  ['عالی'],
#  ['بسیار', 'عالی'],
#  ['همه', 'چیز', 'مرتب', 'و', 'تمیز'],
#  ['فوق\u200cالعاده', 'آرامش', 'بخش'],
#  ['فضای', 'بسیار', 'اختصاصی', 'و', 'دنج'],
#  ['دسترسی', 'سریع', 'به', 'ساحل'],
#  ['اتاق\u200cهای', 'شیک'],
#  ['همه', 'چیز', 'عالی', 'بود'],
#  ['من',
#   'به',
#   'اتفاق',
#   'خانواده',
#   'چهارم',
#   'بهمن',
#   'امسال',
#   'به',
#   'مدت',
#   'چهار',
#   'شب',
#   'کیش',
#   'بودیم'],
#  ['در', 'هتل', 'ماریا', 'پارک', 'اقامت', 'داشتیم'],
#  ['ابتدای',
#   'ورودمان',
#   'به',
#   'خاطر',
#   'همزمانی',
#   'با',
#   'ایام',
#   'پیک',
#   'و',
#   'شلوغی',
#   'هتل',
#   'با',
#   'یک',
#   'ساعت',
#   'تاخیر',
#   'اتاق',
#   'را',
#   'تحویلمان',
#   'دادند'],
#  ['پرسنل',
#   'پذیرش',
#   'هتل',
#   'آنطور',
#   'که',
#   'درشان',
#   'یک',
#   'هتل',
#   'پنج',
#   'ستاره',
#   'تاپ',
#   'هست',
#   'برخورد',
#   'نمی\u200cکنند'],
#  ['از',
#   'این',
#   'مساله',
#   'که',
#   'بگذریم',
#   'این',
#   'هتل',
#   'به',
#   'نظر',
#   'من',
#   'اولین',
#   'و',
#   'بهترین',
#   'هتل',
#   'کیش',
#   'هست'],
#  ['رستوران', 'و', 'کیفیت', 'غذا\u200cهایش', 'عالی', 'هست'],
#  ['اتاق\u200cها',
#   'بسیار',
#   'تمیز',
#   'و',
#   'شیک',
#   'و',
#   'آرام',
#   'و',
#   'دنج',
#   'هستند'],
#  ['محوطه',
#   'و',
#   'فضای',
#   'بیرون',
#   'هتل',
#   'فوق\u200cالعاده',
#   'زیبا',
#   'و',
#   'آرامش',
#   'بخش',
#   'هست'],
#  ['نزدیکی',
#   'به',
#   'دریا',
#   'و',
#   'اسکله',
#   'تفریحی',
#   'نزدیکی',
#   'به',
#   'رستوران',
#   'درجه',
#   'یک',
#   'شاندیز',
#   'صفدری',
#   'که',
#   'انصافا',
#   'هم',
#   'غذا\u200cها',
#   'و',
#   'هم',
#   'موسیقی',
#   'خیلی',
#   'عالی',
#   'بود'],
#  ['ساحل', 'اختصاصی', 'از', 'مزایای', 'این', 'هتل', 'هست'],
#  ['من', 'این', 'هتل', 'را', 'پیشنهاد', 'می\u200cکنم'],
#  ['هتل',
# ...
#   'بود'],
#  ['به', 'دریا', 'نزدیک', 'نبود'],
#  ['همه', 'چیز', 'بسیار', 'عالی'],
#  ['رضایت\u200cبخش', 'بود'],
#  ['محیط', 'آرام', 'و', 'خوبی', 'بود'],
#  ['بهترین', 'خصوصیت', 'این', 'هست', 'که', 'به', 'همه', 'جا', 'نزدیک', 'هست'],
#  ['خیلی',
#   'راحت',
#   'می\u200cشود',
#   'به',
#   'جاذبه\u200c\u200cهای',
#   'گردشگری',
#   'شیراز',
#   'دسترسی',
#   'پیدا',
#   'کرد'],
#  ['بنده',
#   'در',
#   'صورت',
#   'مسافرت',
#   'مجدد',
#   'حتما',
#   'از',
#   'این',
#   'هتل',
#   'استفاده',
#   'خواهم',
#   'کرد'],
#  ['همه',
#   'چیز',
#   'به',
#   'دلیل',
#   'اینکه',
#   'هتل',
#   'در',
#   'مرکز',
#   'شهر',
#   'واقع\u200cشده',
#   'از',
#   'ساعت',
#   '7',
#   'صبح',
#   'به',
#   'بعد',
#   'صدای',
#   'بوق',
#   'ماشین\u200c\u200cها',
#   'در',
#   'اتاق\u200c\u200cها',
#   'خوب',
#   'می\u200cآید'],
#  ['اتاق\u200c\u200cها', 'فاقد', 'پنجره', 'دو', 'جداره', 'و', 'عایق', 'هستند'],
#  ['مکانی', 'با', 'آرامش', 'زیاد', 'و', 'فضای', 'دوستانه'],
#  ['برخورد', 'کارمندان', 'هم', 'عالی', 'است'],
#  ['خیلی', 'عالی', 'بود'],
#  ['آرامش', 'بخش'],
#  ['بسیار', 'آرامش', 'بخش', 'و', 'راحت'],
#  ['نحوه', 'برخورد', 'پرسنل', 'بسیار', 'عالی', 'و', 'حرفه\u200cای'],
#  ['اقامت', 'بسیار', 'خوبی', 'در', 'این', 'هتل', 'داشتم'],
#  ['از', 'هر', 'نظر', 'عالی', 'بود'],
#  ['بسیار', 'لذت', 'بردم', 'از', 'اقامت', 'در', 'این', 'هتل'],
#  ['اگر', 'دوباره', 'بروم', 'شیراز', 'حتما', 'همین', 'هتل', 'می\u200cروم'],
#  ['درمجموع', 'هتل', 'عالی', 'بود'],
#  ['به',
#   'دلیل',
#   'موکت',
#   'پوش',
#   'بودن',
#   'کف',
#   'اتاق\u200c\u200cها',
#   'در',
#   'بعضی',
#   'ساعات',
#   'احساس',
#   'خارش',
#   'شد'],
#  ['نیاز',
#   'به',
#   'شتشوی',
#   'بیشتر',
#   'موکت\u200cها',
#   'با',
#   'دستگاه\u200cهای',
#   'مربوطه',
#   'یا',
#   'استفاده',
#   'از',
#   'پارکت',
#   'توصیه',
#   'می\u200cشود'],
#  ['با',
#   'تشکر',
#   'از',
#   'تمامی',
#   'دست',
#   'اندرکاران',
#   'هتل',
#   'پارس',
#   'همه',
#   'چیز',
#   'خوب',
#   'و',
#   'عالی',
#   'بود'],
#  ['تنها', 'ایراد', 'مربوط', 'به', 'منوی', 'محدود', 'رستوران', 'بود'],
#  ['عالی', 'وتمیز', 'بود'],
#  ['خیلی', 'خوب', 'بود'],
#  ['خوش', 'گذشت'],
#  ['هتل', 'خوب', 'و', 'امکانات', 'کافی', 'و', 'پاکیزه'],
#  ['از', 'کیفیت', 'خشکشویی', 'هتل', 'راضی', 'نبودم'],
#  ['به',
#   'دلیل',
#   'اینکه',
#   'در',
#   'اکثر',
#   'موارد',
#   'بیرون',
#   'از',
#   'هتل\u200cبودم',
#   'نتوانستم',
#   'از',
#   'امکانات',
#   'رستوران',
#   'و',
#   'استخر',
#   'هتل',
#   'استفاده',
#   'کنم'],
#  ['نحوه\u200cی', 'برخورد', 'مناسب', 'بود'],
#  ['خانه\u200cداری', 'همیشه', 'پاسخگو', 'بود'],
#  ['آرامش', 'هم', 'حاکم', 'بود'],
#  ['رضایت', 'کامل', 'را', 'دارم'],
#  ['باسلام'],
#  ['تشکر',
#   'و',
#   'قدردانی',
#   'از',
#   'مدیریت',
#   'هتل',
#   'و',
#   'تمامی',
#   'کارکنان',
#   'هتل',
#   'مخصوصا',
#   'ترانسپورت',
#   'و',
#   'رستوران',
#   'آقایان',
#   'گلبرگ',
#   'و',
#   'عادل',
#   'در',
#   'رستوران',
#   'و',
#   'سایر',
#   'عزیز\u200cان',
#   'که',
#   'اسامی',
#   'آن\u200cها',
#   'در',
#   'خاطر',
#   'نیست'],
#  ['از',
#   'جمله',
#   'حراست',
#   'بخش',
#   'ویلایی',
#   'که',
#   'تا',
#   'صبح',
#   'در',
#   'کنار',
#   'درب',
#   'بزرگ',
#   'جنب',
#   'میدان',
#   'مشغول',
#   'حراست',
#   'و',
#   'نگهبانی\u200cبود',
#   'تا',
#   'امثال',
#   'من',
#   'و',
#   'سایر',
#   'خانواده\u200c\u200cها',
#   'در',
#   'آغوش',
#   'خانواده',
#   'باشیم'],
#  ['عالی', 'بود'],
#  ['عالی', 'بود'],
#  ['پارکینگ', 'نداشت'],
#  ['ما',
#   'را',
#   'مجبور',
#   'کردند',
#   'از',
#   'پارکینگ',
#   'یک',
#   'مجتمع',
#   'تجاری',
#   'دیگری',
#   'در',
#   'آن\u200cسوی',
#   'خیابان',
#   'استفاده',
#   'کنیم'],
#  ['تخت',
#   'دوبل',
#   'برای',
#   '2',
#   'نفر',
#   'بزرگسال',
#   'و',
#   'یک',
#   'کودک',
#   'بسیار',
#   'کوچک',
#   'بود'],
#  ['اتاق\u200c\u200cها', 'فوق\u200cالعاده', 'تنگ', 'بود'],
#  ['سیستم', 'گرمایش', 'مشکل', 'داشت'],
#  ['شب', 'عید', 'بسیار', 'سرد', 'بود'],
#  ['صدای', 'اتاق\u200c\u200cهای', 'دیگر', 'در', 'اتاق', 'ما', 'می\u200cآمد'],
#  ['یک', 'بطری', 'آب', 'هم', 'ندادند'],
#  ['گفتند', 'حتی', 'آب', 'هم', 'بخواهید', 'به', 'حساب', 'مشتری', 'است'],
#  ['چطور', 'به', 'این', 'هتل', 'مجوز', '3', 'ستاره', 'دادند'],
#  ['الله', 'اعلم'],
#  ['رستوران', 'کوچک', 'و', 'کثیف'],
#  ['صبحانه', 'افتضاح'],
#  ['شامپو', 'بدن', 'در', 'حمام', 'نداشتند'],
#  ['توالت', 'مشترک', 'در', 'لابی', 'کثیف', 'بود'],
#  ['برخورد', 'کارکنان', 'چندان', 'رضایت\u200cبخش', 'نبود'],
#  ['حالت', 'همینی', 'که', 'هست', 'در', 'چشمانشان', 'موج', 'می\u200cزد'],
#  ['به',
#   'هیچ',
#   'وجه',
#   'برای',
#   'بار',
#   'دوم',
#   'به',
#   'هتل',
#   'نخواهم',
#   'آمد',
#   'و',
#   'به',
#   'کسی',
#   'توصیه',
#   'نمی\u200cکنم'],
#  ['به',
#   'نظر',
#   'من',
#   'مشکل',
#   'این',
#   'هتل',
#   'صرفا',
#   'به',
#   'عدم',
#   'عایق',
#   'صدا',
#   'بودن',
#   'اتاق\u200c\u200cها',
#   'مربوط',
#   'می\u200cشود'],
#  ['چون',
#   'صدای',
#   'آزاردهنده',
#   'تلویزیون',
#   'اتاق',
#   'همسایه',
#   'واقعا',
#   'مخل',
#   'آسایش',
#   'بود'],
#  ['کیفیت', 'غذا', 'و', 'تمیزی', 'و', 'خدمات', 'عالی', 'بود'],
#  ['هیچ', 'وقت', 'این', 'هتل', 'را', 'دوباره', 'انتخاب', 'نمی\u200cکنم'],
#  ['به', 'شدت', 'پر', 'سر', 'و', 'صدا', 'بود'],
#  ['اصلا', 'نه', 'ظهر', 'نه', 'شب', 'نمی\u200cشد', 'خوابید'],
#  ['دو',
#   'اتاق',
#   'داشتیم',
#   'در',
#   'دو',
#   'روز',
#   'متفاوت',
#   'آنجا\u200cبودیم',
#   'که',
#   'هر',
#   'دو',
#   'گروه',
#   'به',
#   'شدت',
#   'ناراضی',
#   'بودیم'],
#  ['عالی'],
#  ['بسیار', 'از', 'اقامت', 'در', 'این', 'هتل', 'لذت', 'بردم'],
#  ['به', 'دیگران', 'هم', 'پیشنهاد', 'می\u200cکنم'],
#  ['با', 'سلام'],
#  ['متاسفانه',
#   'هر',
#   'بار',
#   'که',
#   'به',
#   'رستوران',
#   'گردان',
#   'هتل',
#   'مراجعه',
#   'کردیم',
#   'دربست',
#   'در',
#   'اختیار',
#   'شخصی',
#   'بود'],
#  ['رستوران',
#   'گردان',
#   'را',
#   'بالا',
#   'هتل',
#   'نمی\u200cساختید',
#   'یا',
#   'به',
#   'طوری',
#   'مدیریت',
#   'می\u200cکردید',
#   'که',
#   'در',
#   'تعطیلات',
#   'که',
#   'مسافر',
#   'زیاد',
#   'هست',
#   'دربست',
#   'در',
#   'اختیار',
#   'شخصی',
#   'یا',
#   'ارگانی',
#   'نباشد'],
#  ['با', 'تشکر'],
#  ['سلام'],
#  ['محیطی', 'کاملا', 'آرام', 'و', 'دنج', 'با', 'کادری', 'مجرب', 'و', 'مودب'],
#  ['در',
#   'مقایسه',
#   'با',
#   'هتل\u200c\u200cهای',
#   'ایران',
#   'کیفیت',
#   'قابل',
#   'قبول',
#   'بود'],
#  ['برخورد', 'کارمندان', 'عالی', 'بود'],
#  ['نداشتن', 'پارکینگ', 'برای', 'من', 'لااقل', 'مشکل', 'خاصی', 'نبود'],
#  ['به',
#   'راحتی',
#   'جلوی',
#   'در',
#   'هتل',
#   'جای',
#   'پارک',
#   'وجود',
#   'داشت',
#   'و',
#   'کارمندان',
#   'هتل',
#   'هم',
#   'خیلی',
#   'کمک',
#   'می\u200cکردند'],
#  ['منوی', 'صبحانه', 'واقعا', 'ضعیف', 'بود'],
#  ['در',
#   'مقایسه',
#   'با',
#   'دو',
#   'هتل',
#   '3',
#   'ستاره',
#   'و',
#   '4',
#   'ستاره',
#   'که',
#   'در',
#   'روزهای',
#   'بعدی',
#   'اقامت',
#   'داشتم'],
#  ['مهم\u200cتر',
#   'از',
#   'همه',
#   'احساس',
#   'مسئولیت',
#   'و',
#   'سرویس',
#   'بچه\u200c\u200cهای',
#   'سامیتا',
#   'بود'],
#  ['خیلی', 'کارشان', 'درست', 'بود'],
#  ['دمشان', 'گرم'],
#  ['محل', 'هتل', 'جای', 'خوبی', 'بود'],
#  ['اتاق\u200c\u200cها', 'تمیز', 'و', 'رسیدگی', 'خوب', 'بود'],
#  ['آسانسور', 'مواقع', 'شلوغی', 'جواب', 'نمی\u200cداد'],
#  ['کافی\u200cشاپ', 'عالی', 'عصر\u200c\u200cها', 'موزیک', 'زنده', 'داشت'],
#  ['در', 'کل', 'به', 'عنوان', 'هتل', '4', 'ستاره', 'قابل', 'قبول', 'بود'],
#  ['همه', 'چه', 'عالی', 'بود'],
#  ['برخورد', 'کارکنان', 'تا', 'امکانات', 'هتل', 'و', 'تمیزی', 'و', 'راحتی'],
#  ['هربار',
#   'دیگر',
#   'که',
#   'شیراز',
#   'بیایم',
#   'مطمئنا',
#   'ستارگان',
#   'را',
#   'انتخاب',
#   'می\u200cکنم'],
#  ['خیلی', 'به', 'ما', 'خوش', 'گذشت', 'شیک', 'و', 'دلنشین', 'بود'],
#  ['هتلی', 'بسیار', 'عالی'],
#  ['شاید', 'بشود', 'گفت', 'تنها', 'مشکل', 'هتل', 'پارکینگ', 'بود'],
#  ['موقعیت', 'مکانی', 'عالی'],
#  ['کیفیت', 'و', 'تمیزی', 'اتاق\u200cها', 'خیلی', 'خوب'],
#  ['صبحانه', 'خوب'],
#  ['رفتار', 'کارکنان', 'خیلی', 'خوب'],
#  ['در', 'کل', 'خیلی', 'راضی', 'بودم'],
#  ['هتل', 'در', 'حد', 'سه', 'ستاره', 'است'],
#  ['از',
#   'لحاظ',
#   'پاکیزگی',
#   'و',
#   'آرامش',
#   'در',
#   'اتاق',
#   'در',
#   'حد',
#   'مسافر',
#   'خانه',
#   'می\u200cباشد'],
#  ['نکته',
#   'مثبت',
#   'کارکنان',
#   'در',
#   'سرویس\u200cدهی',
#   'در',
#   'قسمت',
#   'صبحانه',
#   'می\u200cباشد'],
#  ['صبحانه', 'هم', 'در', 'حد', '3', 'ستاره'],
#  ['محیط', 'هتل', 'خوب', 'بود'],
#  ['کارکنان',
#   'بخش',
#   'پذیرش',
#   'بسیار',
#   'بی\u200cمسئولیت\u200cبودند',
#   'و',
#   'اصلا',
#   'قابل',
#   'گذشت',
#   'نبودند'],
#  ['هتل', 'اصلا', 'درحد', 'هتل', '5', 'ستاره', 'نیست'],
#  ['قدیمی', 'هست'],
#  ['اتاق\u200cهای',
#   'لوکس',
#   'بیرون',
#   'از',
#   'هتل',
#   'خوب\u200cبود',
#   'که',
#   'آن',
#   'هم',
#   'چون',
#   'داخل',
#   'هتل',
#   'نیست',
#   'حس',
#   'هتل',
#   'بودن',
#   'در',
#   'هتل',
#   'ندارد'],
#  ['ویلایی', 'و', 'مناسب', 'افراد', 'مسن', 'نیست', 'چون', 'پله', 'دارد'],
#  ['برخورد', 'کارکنان', 'خوب\u200cبود', 'اما', 'رسپشن', 'نه'],
#  ['مزیت', 'اصلی', 'نزدیک', 'پاساژ', 'و', 'دریا', 'است'],
#  ['در',
#   'ضمن',
#   'دید',
#   'دریا',
#   'ندارد',
#   'چون',
#   'ویو',
#   'دریا',
#   'خواستیم',
#   'گفتن',
#   'هتل',
#   'ویو',
#   'دریا',
#   'ندارد'],
#  ['یک', 'چایساز', 'داخل', 'اتاق', 'نبود'],
#  ['مسافرخانه', 'چایساز', 'دارد'],
#  ['من', 'و', 'همسرم', 'برای', 'ماه', 'عسل', 'رفته', 'بودیم'],
#  ['برخورد',
#   'پرسنل',
#   'و',
#   'تمیزی',
#   'اتاق\u200cها',
#   'عالی',
#   'بودن',
#   'من',
#   'خیلی',
#   'راضی',
#   'بودیم'],
#  ['باز',
#   'هم',
#   'می\u200cخواهیم',
#   'همان',
#   'هتل',
#   'را',
#   'برای',
#   'رفتن',
#   'به',
#   'کیش',
#   'انتخاب',
#   'کنیم'],
#  ['به', 'مراکز', 'خرید', 'خیلی', 'نزدیک', 'است'],
#  ['در', 'چند', 'قدمی', 'مرکز', 'تجاری', 'کیش', 'است'],
#  ['به', 'چند', 'بازار', 'هم', 'نزدیک', 'است'],
#  ['به',
#   'ساحل',
#   'هم',
#   'نسبتا',
#   'نزدیک',
#   'است',
#   'که',
#   'می\u200cشود',
#   'پیاده',
#   'هم',
#   'رفت'],
#  ['ما',
#   'در',
#   'سوئیت',
#   'یک',
#   'خوابه',
#   'محوطه',
#   'هتل\u200cبودیم',
#   'که',
#   'خیلی',
#   'شیک',
#   'و',
#   'تمیز',
#   'و',
#   'بزرگ\u200cبود',
#   'و',
#   'دارای',
#   'تراس',
#   'و',
#   'پنجره\u200c\u200cهای',
#   'بزرگ\u200cبود',
#   'و',
#   'نمای',
#   'دریا',
#   'هم',
#   'داشت'],
#  ['کارکنان',
#   'رفتار',
#   'عالی',
#   'دارند',
#   'و',
#   'به',
#   'مسافران',
#   'خیلی',
#   'احترام',
#   'می\u200cگذارند'],
#  ['کیفیت', 'صبحانه', 'عالی', 'بود'],
#  ['نهار', 'و', 'شام', 'هم', 'مناسب', 'است'],
#  ['دارای', 'موزیک', 'زنده', 'در', 'رستوران', 'بود'],
#  ['قیمت', 'بالایی', 'دارد'],
#  ['هتل', 'امکانات', 'خوبی', 'دارد'],
#  ['روشنایی', 'اتاق', 'کم', 'بود'],
#  ['در', 'اتاق', 'ساعت', 'دیواری', 'هم', 'موجود', 'نبود'],
#  ['نظافت',
#   'و',
#   'پاکیزگی',
#   'و',
#   'برخورد',
#   'مودبانه',
#   'پرسنل',
#   'خیلی',
#   'رضایت\u200cبخش',
#   'بود'],
#  ['امکانات', 'و', 'رستوران', 'و', 'غذا', 'هم', 'عالی'],
#  ['استخر', 'خیلی', 'تمیز', 'و', 'روبه', 'راه', 'نبود'],
#  ['در', 'کل', 'هتل', 'خیلی', 'خوبی'],
#  ['سلام'],
#  ['ما',
#   'اواخر',
#   'آذر',
#   'یک',
#   'سوئیت',
#   '4',
#   'نفره',
#   'گرفتیم',
#   'در',
#   'هتل',
#   'شایگان'],
#  ['به', 'نظر', 'من', 'هتل', 'شیک', 'و', 'تمیزی', 'هست'],
#  ['برخورد', 'کارکنان', 'و', 'پرسنل', 'در', 'حد', 'خوب', 'است'],
#  ['پیشنهاد',
#   'می\u200cکنم',
#   'برای',
#   'سفر',
#   'به',
#   'جزیره',
#   'زیبای',
#   'کیش',
#   'حتما',
#   'این',
#   'هتل',
#   'را',
#   'انتخاب',
#   'کنید'],
#  ['من', 'از', 'این', 'هتل', 'خیلی', 'راضی', 'بودم'],
#  ['از',
#   'نظر',
#   'موقعیت',
#   'مکانی',
#   'دسترسی',
#   'راحت',
#   'و',
#   'سریع',
#   'به',
#   'بازار\u200cها',
#   'و',
#   'مراکز',
#   'تفریحی'],
#  ['برخورد', 'واقعا', 'دوستانه', 'پرسنل', 'خوب', 'بود'],
#  ['آنجا',
#   'واقعا',
#   'کاری',
#   'می\u200cکند',
#   'که',
#   'هر',
#   'کسی',
#   'دوست',
#   'دارد',
#   'تجربه',
#   'مسافرت',
#   'به',
#   'کیش',
#   'را',
#   'دوباره',
#   'کند'],
#  ['من',
#   'و',
#   'خانواده\u200cام',
#   'اگر',
#   'خدا',
#   'بخواهد',
#   'دوباره',
#   'امسال',
#   'هم',
#   'می\u200cخواهیم',
#   'به',
#   'همین',
#   'هتل',
#   'بریم'],
#  ['من', 'و', 'همسرم', 'برای', 'ماه', 'عسل', 'رفته', 'بودیم'],
#  ['واقعا', 'راضی', 'بودیم'],
#  ['برخورد',
#   'کارکنان',
#   'و',
#   'وضعیت',
#   'ظاهری',
#   'و',
#   'نظافت',
#   'هتل',
#   'عالی',
#   'بود'],
#  ['توصیه', 'می\u200cکنم', 'امتحان', 'کنید'],
#  ['این', 'هتل', '5', 'ستار', 'هست', 'نه', '4', 'ستاره'],
#  ['لطف', 'کنید', 'در', 'سایت', 'درست', 'کنید'],
#  ['ممنون'],
#  ['نسبت', 'به', 'هتل\u200cهای', 'دیگر', 'خیلی', 'بهتر', 'هست'],
#  ['متاسفانه', 'برخورد', 'خوبی', 'ندارند', 'دیگر', 'نمی\u200cرویم'],
#  ['هتل', 'نسبت', 'به', 'قیمت', 'امکانات', 'خوبی', 'ندارد'],
#  ['بسیار', 'قدیمیه', 'ونیاز', 'به', 'بازسازی', 'دارد'],
#  ['سر',
#   'و',
#   'صدای',
#   'زیادی',
#   'دارد',
#   'در',
#   'مجموع',
#   'راضی\u200cکننده',
#   'نیست'],
#  ['عالی', 'بود'],
#  ['خیلی', 'گران', 'هم', 'بود'],
#  ['خیلی', 'جالب\u200cبود', 'مخصوصا', 'موزه\u200c\u200cها'],
#  ['به', 'نظر', 'من', 'رامسر', 'یک', 'شهر', 'توریستی', 'اروپا\u200cیی', 'هست'],
#  ['فضای', 'بسیار', 'مطلوب'],
#  ['طبیعتی', 'زیبا'],
#  ['برخورد', 'مودبانه', 'پرسنل'],
#  ['غذای', 'عالی'],
#  ['خاطره', 'شیرینی', 'را', 'برایمان', 'بوجود', 'آورد'],
#  ['انتخاب', 'مجدد', 'ما', 'خواهد', 'بود'],
#  ['هتل', 'عالی', 'و', 'دنج', 'است'],
#  ['بسیار', 'شیک', 'و', 'مرتب', 'است'],
#  ['من', 'در', 'زمستان', 'رفته\u200cبودم', 'اتاق', 'خیلی', 'سرد', 'بود'],
#  ['وایرلس', 'طبقه', 'همکف', 'فعال', 'بود'],
#  ['باسلام'],
#  ['رزرواسیون',
#   'بموقع',
#   'و',
#   'تحویل',
#   'اطاق\u200cها',
#   'در',
#   'شهر',
#   'مربوطه',
#   'نیز',
#   'بلافاصله',
#   'و',
#   'خوب',
#   'بود'],
#  ['از',
#   'لحاظ',
#   'تمیزی',
#   'هتل',
#   'فرسوده',
#   'و',
#   'اطاق\u200cها',
#   'نیز',
#   'به',
#   'نقاشی',
#   'و',
#   'یا',
#   'تعویض',
#   'کاغذ\u200cدیواری',
#   'نیاز',
#   'دارد'],
#  ['موکت', 'کف', 'اطاق\u200cها', 'نیز', 'کثیف', 'بودند'],
#  ['باتشکر'],
#  ['عالی'],
#  ['عالی'],
#  ['عالی'],
#  ['تهویه', 'دستشویی', 'و', 'آسانسور\u200cها', 'نیاز', 'به', 'تقویت', 'دارد'],
#  ['در', 'لوازم', 'بهداشتی', 'ژیلت', 'قرار', 'داده', 'شود'],
#  ['آرایشگاه',
#   'در',
#   'اطرف',
#   'هتل',
#   'پاساژ',
#   'و',
#   'یا',
#   'داخل',
#   'هتل',
#   'ایجاد',
#   'گردد'],
#  ['با', 'سلام'],
#  ['من',
#   'به',
#   'همراه',
#   'همسرم',
#   'تولد',
#   'امام',
#   'رضا',
#   'در',
#   'این',
#   'هتل',
#   'اقامت',
#   'داشتیم'],
#  ['از',
#   'نظر',
#   'نظافت',
#   'و',
#   'پاکیزگی',
#   'و',
#   'کیفیت',
#   'غذا',
#   'بسیار',
#   'مناسب',
#   'بود'],
#  ['فضای', 'مناسبی', 'برای', 'مسافران', 'داشت'],
#  ['سرویس\u200c\u200cهای',
#   'رفت',
#   'و',
#   'آمد',
#   'به',
#   'حرم',
#   'هم',
#   'خیلی',
#   'خوب',
#   'و',
#   'برنامه\u200cریزی\u200cشده\u200cبود'],
#  ['متاسفانه',
#   'رفتار',
#   'کارکنان',
#   'پذیرش',
#   'هتل',
#   'اصلا',
#   'در',
#   'حد',
#   'یک',
#   'هتل',
#   'چهار',
#   'ستاره',
#   'نبود'],
#  ['بدون',
#   'نظم',
#   'و',
#   'ترتیب',
#   'و',
#   'حتی',
#   'بدون',
#   'برنامه\u200cریزی',
#   'مناسب',
#   'باعث',
#   'معطلی',
#   'حدود',
#   'دو',
#   'ساعتی\u200cشده\u200cبودند'],
#  ['اتاق\u200c\u200cها',
#   'را',
#   'بعد',
#   'از',
#   'حدود',
#   'دو',
#   'ساعت',
#   'معطلی',
#   'ساعت',
#   '3',
#   'بعد',
#   'از',
#   'ظهر',
#   'تحویل',
#   'دادند',
#   'آن',
#   'هم',
#   'با',
#   'کلی',
#   'بحث',
#   'و',
#   'گفتگو'],
#  ['ساعت', 'تحویل', 'اتاق', 'دو', 'می\u200cباشد'],
#  ['موقع',
#   'خروج',
#   'هم',
#   'با',
#   'مشکلات',
#   'مشابه',
#   'زمان',
#   'پذیرش',
#   'روبرو',
#   'بودیم'],
#  ['زمان',
#   'زیادی',
#   'را',
#   'معطل',
#   'شدیم',
#   'تا',
#   'جایی',
#   'که',
#   'اگر',
#   'مدیریت',
#   'محترم',
#   'هتل',
#   'شخصا',
#   'نیامده\u200cبودند',
#   'خیلی',
#   'از',
#   'مسافران',
#   'ممکن\u200cبود',
#   'پروازشان',
#   'را',
#   'از',
#   'دست',
#   'بدهند'],
#  ['انتظار',
#   'می\u200cرود',
#   'در',
#   'زمان\u200c\u200cهای',
#   'شلوغ',
#   'و',
#   'پرتردد',
#   'که',
#   'کاملا',
#   'قابل',
#   'پیش\u200cبینی',
#   'هست',
#   'برنامه',
#   'ریزی\u200cها',
#   'قبل',
#   'از',
#   'ورود',
#   'مهمان',
#   'انجام',
#   'بشود'],
#  ['همچنین',
#   'به',
#   'مسئولین',
#   'پذیرش',
#   'که',
#   'تقریبا',
#   'جزئ',
#   'اولین',
#   'نفراتی',
#   'هستند',
#   'که',
#   'میهمان',
#   'به',
#   'محض',
#   'ورود',
#   'با',
#   'آن\u200cها',
#   'روبرو',
#   'می\u200cشود',
#   'آموزش\u200c\u200cهای',
#   'لازم',
#   'نحوه',
#   'رفتار',
#   'با',
#   'میهمان\u200cها',
#   'داده',
#   'بشود',
#   'تا',
#   'رضایتمندی',
#   'بیشتری',
#   'برای',
#   'هتل',
#   'به',
#   'ارمغان',
#   'بیاورد'],
#  ['در',
#   'صورت',
#   'امکان',
#   'ساعت\u200c\u200cهای',
#   'استفاده',
#   'از',
#   'استخر',
#   'یک',
#   'روزه',
#   'باشد'],
#  ['امکان',
#   'استفاده',
#   'در',
#   'ساعت\u200c\u200cهای',
#   'ظهر',
#   'و',
#   'غروب',
#   'نیز',
#   'باشد'],
#  ['از', 'تمامی', 'پرسنل', 'این', 'هتل', 'کمال', 'تشکر', 'را', 'دارم'],
#  ['عالی'],
#  ['نسبت',
#   'به',
#   'هزینه\u200cای',
#   'که',
#   'پرداخت',
#   'می\u200cکنید',
#   'بسیار',
#   'مقرون',
#   'به',
#   'صرفه',
#   'است'],
#  ['مسئله\u200cای',
#   'که',
#   'ممکن',
#   'است',
#   'مزاحمت',
#   'ایجاد',
#   'نماید',
#   'عدم',
#   'رعایت',
#   'سکوت',
#   'توسط',
#   'میهمانان',
#   'غیر',
#   'ایرانی',
#   'بود'],
#  ['نهایت',
#   'جا',
#   'دارد',
#   'از',
#   'مدیریت',
#   'و',
#   'امانت\u200cداری',
#   'خوب',
#   'هتل',
#   'که',
#   'برای',
#   'من',
#   'واقعا',
#   'جای',
#   'تعجب',
#   'داشت',
#   'تشکر',
#   'کنم'],
#  ['ایشان',
#   'شخصا',
#   'در',
#   'مورد',
#   'یکی',
#   'از',
#   'وسایلی',
#   'که',
#   'بنده',
#   'در',
#   'هتل',
#   'جا',
#   'گذاشته\u200cبودم',
#   'پیگیری',
#   'کردند',
#   'و',
#   'همراه',
#   'هدیه\u200cای',
#   'آن',
#   'را',
#   'به',
#   'آدرس',
#   'من',
#   'پست',
#   'نمودند'],
#  ['واقعا',
#   'از',
#   'مدیریت',
#   'و',
#   'کارکنان',
#   'سپاسگزارم',
#   'و',
#   'امیدوارم',
#   'با',
#   'استمرار',
#   'این',
#   'کردار',
#   'نیک',
#   'آبروی',
#   'مکدر\u200cشده\u200cفرهنگ',
#   'ما',
#   'دوباره',
#   'احیا',
#   'شود'],
#  ['با', 'توجه', 'به', 'هتل', 'سه', 'ستاره', 'خوب', 'است'],
#  ...]

# %% [markdown]
# + size: (default 100) The number of dimensions of the embedding, e.g. the length of the dense vector to represent each token (word).
# + window: (default 5) The maximum distance between a target word and words around the target word.
# + min_count: (default 5) The minimum count of words to consider when training the model; words with an occurrence less than this count will be ignored.
# + workers: (default 3) The number of threads to use while training.
# + sg: (default 0 or CBOW) The training algorithm, either CBOW (0) or skip gram (1)

# %% [markdown]
# If you have a lot of cores, as most modern computers do, I strongly encourage you to increase workers to match the number of cores (e.g. 8)

# %%
# %%time
model = Word2Vec(sentences = corpus,
                 size = 100,
                 window = 3,
                 min_count = 1,
                 workers = 1,
                 iter = 100,
                 sg = 1)
# Out:
# Wall time: 32.5 s

# %%
words = list(model.wv.vocab)
words
# Out:
# ['سلام',
#  'با',
#  'توجه',
#  'به',
#  'قیمت',
#  'و',
#  'انتظاراتی',
#  'که',
#  'از',
#  'یک',
#  'هتل',
#  '5',
#  'ستاره',
#  'داریم',
#  'اصلا',
#  'ابدا',
#  'خوب',
#  'نبود',
#  'نظافت',
#  'اطاقها',
#  'در',
#  'حد',
#  'سه',
#  'ستاره\u200cهای',
#  'دبی',
#  'بود',
#  'غذا',
#  'خیلی',
#  'گران',
#  'سرویس',
#  'اتاق',
#  'آنقدر',
#  'تاخیر',
#  'می\u200cآمد',
#  'مجبور\u200cبودیم',
#  'سفارش',
#  'را',
#  'لغو',
#  'کنیم',
#  'ظروف',
#  'رستوران',
#  'قدیمی',
#  'کدر',
#  'آکسسوار',
#  'جدیدها',
#  'هم',
#  'کیفیت',
#  'پائینی',
#  'برخوردار',
#  'اگر',
#  'انعام',
#  'می\u200cدادیم',
#  'رفتار',
#  'پرسنل',
#  'غیر',
#  'اینصورت',
#  'رفتارشان',
#  'بدوی',
#  'روستایی',
#  'مآبانه',
#  'ایتالیایی',
#  'دارای',
#  'کارکنان',
#  'نیمه',
#  'حرفه',
#  'ایی',
#  'تا',
#  'حدی',
#  'قابل',
#  'قبول',
#  'صورت',
#  'اسمی',
#  'خانه\u200cداری',
#  '24',
#  'ساعته',
#  'ساعت',
#  '9',
#  'شب',
#  'درخواست',
#  'آب',
#  'معدنی',
#  'کردم',
#  '11',
#  'آوردند',
#  'من',
#  'نپذیرفتم',
#  'ولی',
#  'موقع',
#  'تسویه',
#  'حساب',
#  'کرده',
#  'بودند',
#  '100',
#  'درصد',
#  'مطمئن',
#  'هستم',
#  'واقعا',
#  'بخش',
#  'خصوصی',
#  'واگذار',
#  'کنند',
#  'ارائه',
#  'خدمات',
#  'نحو',
#  'چشمگیری',
#  'افزایش',
#  'پیدا',
#  'می\u200cکند',
#  'نزدیک',
#  'نمایشگاه',
#  'نکته',
#  'خاص',
#  'برای',
#  'آن',
#  'حرفه\u200cای',
#  'کمتر',
#  'هتل\u200cهای',
#  'ایران',
#  'دیده',
#  'می\u200cشود',
#  'یکی',
#  'سفرهای',
#  'کاری',
#  'آقای',
#  'علی',
#  'دایی',
#  'تیمش',
#  'فکر',
#  'کنم',
#  'پرسپولیس\u200cبود',
#  'دو',
#  'سال',
#  'پشت',
#  'سر',
#  'روز',
#  'چهار',
#  'این',
#  'اقامت',
#  'داشتم',
#  'به\u200cطور',
#  'کلی',
#  'رو',
#  'دوست',
#  'البته',
#  'امسال',
#  'علت',
#  'بالا',
#  'دیگری',
#  'انتخاب',
#  'می\u200cکنم',
#  'اتاق\u200cها',
#  'گردگیری\u200cنشده\u200cبود',
#  'کف',
#  'موکت\u200cها',
#  'تمیز',
#  'برنامه',
#  'استخرها',
#  'مخصوصا',
#  'خانم\u200cها',
#  'بار',
#  'استخر',
#  'دست',
#  'تعمیر',
#  'نظر',
#  'پنج',
#  'نمی\u200cخورد',
#  'معمولی',
#  'هست',
#  'خوش',
#  'برخوردی',
#  'دارد',
#  'نه',
#  'بیشتر',
#  'آماده\u200cسازی',
#  'چه',
#  'درون',
#  'کمی',
#  'انجام',
#  'فضاسازی',
#  'استفاده',
#  'طبیعیت',
#  'محوطه',
#  'باید',
#  'بهتر',
#  'باشد',
#  'مراجعه',
#  'کادر',
#  'گفتند',
#  'اتاقتان',
#  'آماده',
#  'نیست',
#  'چند',
#  'لابی',
#  'منتظر',
#  'ماندیم',
#  'فرنگی',
#  'خراب',
#  'مجبور',
#  'شدیم',
#  'عوض',
#  'راضی',
#  'نبودیم',
#  'بسیار',
#  'عالی',
#  'است',
#  'جز',
#  'گردان',
#  'همه',
#  'چیز',
#  '4',
#  'انتظار',
#  'می\u200cرود',
#  'چای',
#  'ساز',
#  'صبحانه',
#  'سریعا',
#  'شارژ',
#  'می\u200cشد',
#  'محیط',
#  'نور',
#  'کافی',
#  'نداشت',
#  'حمام',
#  'کوچک',
#  'قبلا',
#  'داخل',
#  'جدیدا',
#  'مشکل',
#  'رفع\u200cشده\u200cاست',
#  'سابقه',
#  'کار',
#  'دارم',
#  'محیطی',
#  'کارمندان',
#  'مودب',
#  'غذا\u200cهای',
#  'خوشمزه',
#  'باکیفیت',
#  'مناسب',
#  'خسته',
#  'نباشید',
#  'امکانات',
#  'درحد',
#  '5ستاره',
#  'ظاهرخوبی',
#  'محل',
#  'قرارگیری',
#  'شلوغ',
#  'الودگی',
#  'صوتی',
#  'وبصری',
#  'هوا',
#  'زیاد',
#  'خوشم',
#  'آمد',
#  'عباسی',
#  'شیک',
#  'وزیبا',
#  'برخورد',
#  'بودم',
#  'حیاط',
#  'جذاب',
#  'منفی',
#  'دیدم',
#  'مهمان\u200c\u200cهای',
#  'مقیم',
#  'هستند',
#  'ما',
#  'خالی',
#  'شدن',
#  'میز',
#  'شام',
#  'معطل',
#  'کاملا',
#  'قید',
#  'قسمت',
#  'کافی\u200cشاپ',
#  'قهوه',
#  'خانه',
#  'سنتی',
#  'زدیم',
#  'دقیقا',
#  'مثل',
#  'اینکه',
#  'مهمان',
#  'دعوت',
#  'کنید',
#  'عقد',
#  'بعد',
#  'کادو',
#  'داد',
#  'خانواده',
#  'درجه',
#  'بنشینند',
#  'روی',
#  'مبل',
#  'غریبه',
#  'وسط',
#  'مجلس',
#  'بایستید',
#  'پایانی',
#  'آنجا',
#  'بودیم',
#  'بنده',
#  'پیشخدمت\u200c\u200cها',
#  'زیرین',
#  'محفظه\u200cای',
#  'پرتقال',
#  'وجود',
#  'واقع',
#  'مقداری',
#  'سر\u200cریز',
#  'درونش',
#  'ریخته',
#  'برگرداند',
#  'دوباره',
#  'ظرف',
#  'فضای',
#  'سبز',
#  'آثار',
#  'اطاق',
#  '1220',
#  'بعنوان',
#  'سوییت',
#  'نمی\u200cباشد',
#  '1008',
#  'کامل',
#  'پرسنلش',
#  'اینقدر',
#  'بهانه',
#  'دولتی',
#  'بودن',
#  'نمی\u200cکردند',
#  'حداقل',
#  'افتضاح',
#  'بد',
#  'اتاق\u200c\u200cها',
#  'ابتدائی\u200c\u200cترین',
#  'بی\u200cبهره',
#  'قبل',
#  'انقلاب',
#  'الان',
#  'مسافرخانه',
#  'همان',
#  'اول',
#  'رفتیم',
#  'جالب',
#  'انتظارآن',
#  'نداشتیم',
#  'پارک',
#  'خوابیدن',
#  'اصفهان',
#  'گزینه',
#  'متمایز',
#  'هتل\u200c\u200cهای',
#  'دیگر',
#  'پارکینگ',
#  'فضایش',
#  'کم',
#  'خودرو',
#  'جا',
#  'ندارد',
#  'درحدهتل',
#  '3',
#  'برایش',
#  'دربان',
#  'گرفته',
#  'پذیرش',
#  'رفتن',
#  'پیشنهاد',
#  'نمی\u200cکنم',
#  'باورکردنی',
#  'زیبا',
#  'ورویایی',
#  'دلم',
#  'نمی\u200cخواست',
#  'بیرون',
#  'بروم',
#  'توصیه',
#  'حتما',
#  'مانده',
#  'فاسد',
#  'طوری',
#  '6',
#  'نفر',
#  'مسموم',
#  'همچنین',
#  'رستورانی',
#  'انتظاری',
#  'نمی\u200cرفت',
#  'زیبایی',
#  'نحوه',
#  'تنها',
#  'موردی',
#  'خوشایند',
#  'درمورد',
#  'رزرواسیون',
#  'وتحویل',
#  'آپارتمان',
#  'چهارنفره',
#  'رزروکرده',
#  'نفره',
#  'دادند',
#  'مهم',
#  'تفاوت',
#  'پرداخت',
#  'نکردند',
#  'رویائی',
#  'رویایی',
#  'مرسی',
#  'خوبی',
#  'حس',
#  'آدم',
#  'می\u200cدهد',
#  'حداکثر',
#  'می\u200cتوان',
#  'تصور',
#  'کرد',
#  'هستید',
#  'باز',
#  'هجوم',
#  'میهمان\u200cها',
#  'بیش',
#  'خارج',
#  'آرامش',
#  'میهمانان',
#  'ومهمان',
#  'نوازانه',
#  'ممنون',
#  'اوین',
#  'بهتری',
#  'نسبت',
#  'بعضی',
#  'تهران',
#  'داشتن',
#  'دلچسب',
#  'سرویس\u200cدهی',
#  'اتاق\u200c\u200cهای',
#  'نسبتا',
#  'مجهز',
#  'امتیاز\u200c\u200cهای',
#  'امکاناتش',
#  'کشور\u200cهای',
#  'آنتالیا',
#  'جزایر',
#  'هاوایی',
#  'رفته\u200cبودم',
#  'قیاس',
#  'اینجا',
#  'متوسط',
#  'پایین\u200c\u200cتر',
#  'نظیر',
#  'بی\u200cنظیر',
#  'کادرجنتلمن',
#  'واقعی',
#  '20',
#  'منوی',
#  'متنوع',
#  'کارشناسی\u200cشده',
#  'گاهی',
#  'اوقات',
#  'صدای',
#  'متناوب',
#  'گوش',
#  'میرسید',
#  'حدس',
#  'خرابی',
#  'آسانسور\u200cها',
#  'کل',
#  'جای',
#  'تشکر',
#  'مریزاد',
#  'اشکالها\u200cی',
#  'بزرگ',
#  'شلوغی',
#  'انسان',
#  'احساس',
#  'هیچ',
#  'وجه',
#  'حالت',
#  'داشت',
#  'مسافر',
#  'راحتی',
#  'خوراکی',
#  'سرو',
#  'نمی\u200cشود',
#  'مورد',
#  'سوال',
#  'رسپشن',
#  'تندی',
#  'جواب',
#  'خیر',
#  'تمیزی',
#  'خصوصا',
#  'زنده',
#  'رود',
#  'جاری',
#  'نمای',
#  'تعداد',
#  'میهمان',
#  'سالن',
#  'خوردم',
#  'طبقه',
#  '14',
#  'نمایی',
#  'شهر',
#  'مشهد',
#  'انتظارم',
#  'مجلل',
#  'مهر',
#  'فوق\u200cالعاده',
#  'باتشکر',
#  'باشعور',
#  'سفر',
#  'بعدی',
#  'ترانسفر',
#  'بدرقه',
#  'مجموعه',
#  'آبی',
#  'امتحان',
#  'بهشتی\u200cبود',
#  'واسه',
#  'خودش',
#  'همسرم',
#  'یاد',
#  'ماندنی',
#  'تجربه',
#  'کردیم',
#  'درست',
#  'فک',
#  'بهترین',
#  'انتحاب',
#  'همچین',
#  'مجللی',
#  'اقامتم',
#  'بالایی',
#  'شاهد',
#  'پوشش',
#  'لباس',
#  'پذیرایی',
#  'خوراک',
#  'مناسب\u200cتری',
#  'حالا',
#  'پایین',
#  'نگاه',
#  'نکرده',
#  'اتفاقا',
#  'چادری',
#  'نرفتم',
#  'داییم',
#  'رفته',
#  'تعریف',
#  'همیشه',
#  'می\u200cروم',
#  'خوب\u200cبود',
#  'اطلاع\u200cرسانی',
#  'درباره',
#  'قسمت\u200cهای',
#  'مختلف',
#  'ضمن',
#  'سبک',
#  'عربی',
#  'ایرانی\u200cها',
#  'پیشینه',
#  'تاریخی',
#  'باستانی',
#  'مجموع',
#  'می\u200cتواند',
#  'درویشی',
#  'ایشان',
#  'آرزوی',
#  'سلامتی',
#  'سربلندی',
#  'پیروزی',
#  'جوری',
#  'تعریفش',
#  'شنیدم',
#  '٥',
#  'تاپ',
#  'محسوب',
#  'می\u200cتوانست',
#  'این\u200cها',
#  'ضعف\u200cهای',
#  'زیادی',
#  'دوستانم',
#  '2',
#  'داشتیم',
#  'مدیریت',
#  'کلاس',
#  'هما',
#  'مقایسه',
#  'صرفا',
#  'عرب\u200cها',
#  'ساخته\u200cشده',
#  'باب',
#  'طبع',
#  'آن\u200cها',
#  'معماری',
#  'دکوراسیون',
#  'مدرنی',
#  'هزینه\u200cای',
#  'مشابه',
#  'تبلیغات',
#  'شما',
#  'ساده',
#  'آینه',
#  'دراتاق',
#  'خواب',
#  'مجاور',
#  'عرب',
#  'سکوت',
#  'رعایت',
#  'رغم',
#  'فصل',
#  'طرحهایی',
#  'سایت',
#  'دیده\u200cبودیم',
#  'اتاقی',
#  'طبقات',
#  'هتل\u200cبود',
#  'مسوول',
#  'خانم',
#  'اسب\u200cها',
#  'رستوران\u200c\u200cها',
#  'آخرین',
#  'سفرم',
#  'شد',
#  'بخاطر',
#  'بدو',
#  'ورود',
#  'فرودگاه',
#  'محبت\u200cآمیز',
#  'مواجه',
#  'شدم',
#  'نمی\u200cدانم',
#  'چرا',
#  'لحظه',
#  'زدم',
#  'قبلی',
#  'فرق',
#  'خواهد',
#  'مسیر',
#  'طول',
#  'اندک',
#  'وقتی',
#  'وارد',
#  'محسورم',
#  'متوجه',
#  'بلکه',
#  'مودبانه',
#  'پرسنل\u200cبود',
#  'مرا',
#  'تحت',
#  'تاثیر',
#  'قرا',
#  'داده',
#  'کمال',
#  'احترام',
#  'باور',
#  'احساسی',
#  'خودم',
#  'میشوم',
#  'راستی',
#  'چون',
#  'پروازم',
#  'صبح',
#  'زود\u200cبود',
#  'سریع',
#  'رفتم',
#  'بگویم',
#  'مدرن',
#  'رستوران\u200cها',
#  'هنوز',
#  'امکان',
#  'لحاظ',
#  'مالی',
#  'نکرده\u200cام',
#  'یکروز',
#  'می\u200cآیم',
#  'امید',
#  'دیدار',
#  'مشغول',
#  'بشوم',
#  'امکانش',
#  'افرادی',
#  'می\u200cخواهد',
#  'سوابق',
#  'امکان\u200cپذیر',
#  'دلیل',
#  'وضعیت',
#  'متاسفانه',
#  'نمی\u200cتوانم',
#  'وبسایت',
#  'آرزو',
#  'بتوانم',
#  'هفته',
#  'می\u200cباشد',
#  'خود',
#  'ایراد',
#  'سیستم',
#  'رزرو',
#  'اینترنتی',
#  'ضعیفی',
#  'درحال',
#  'حاضر',
#  'سعی',
#  'دهم',
#  'موفق',
#  'نمیشوم',
#  'اتاقهای',
#  'دبل',
#  'زیبائی',
#  'بر',
#  'خلاف',
#  'ایرادهای',
#  'مهمی',
#  'مدیرت',
#  'محترم',
#  'لازم',
#  'صدد',
#  'رفع',
#  'برآید',
#  'اولین',
#  'چیزی',
#  'هتلی',
#  'سطح',
#  'میرود',
#  'خدشه',
#  'دار\u200cشده\u200cاست',
#  'موقعیت',
#  'اصلی',
#  'اشراف',
#  'موجود',
#  'نوع',
#  'خلاقانه',
#  'زیباست',
#  'هر',
#  'قاشق',
#  'چنگال',
#  'موسیقی',
#  'تمامی',
#  'اتاقها',
#  'حتی',
#  'وضوح',
#  'شنیده',
#  'بدجوری',
#  'مخل',
#  'جنس',
#  'قطر',
#  'دیوارهای',
#  'بین',
#  'گونه\u200cای',
#  'اندکی',
#  'بلند',
#  'صحبت',
#  'یا',
#  'معمول',
#  'تلویزیون',
#  'بلند\u200cتر',
#  'شنیدن',
#  'همسایه',
#  'اتاقم',
#  'تذکر',
#  'کند',
#  'مجبور\u200cبودم',
#  'تحمل',
#  'جابجائی',
#  'بالاتر',
#  'میسر',
#  'نشد',
#  'مطمئنا',
#  'تغییر',
#  'مشکلات',
#  'مذکور',
#  'حل',
#  'دوستان',
#  'عزیز',
#  'صاحب',
#  'والا',
#  'متشخصی',
#  'تمام',
#  'تلاششان',
#  'جهت',
#  'رفاه',
#  'حال',
#  'بسی',
#  'دیدنی',
#  'ضعیف',
#  'عمل',
#  'می\u200cکنند',
#  'اشتباهی',
#  'رزرو\u200cشده\u200cبود',
#  'جمله',
#  'دوم',
#  'نپسندیدم',
#  'چادر',
#  'مخالف',
#  'نیستم',
#  'خودشان',
#  'پا',
#  'گیر',
#  'شیک\u200cتر',
#  'عین',
#  'اسلامی',
#  'برود',
#  'میبینی',
#  'ناخود',
#  'آگاه',
#  'بانوان',
#  'پلیس',
#  'می\u200cافتید',
#  'موارد',
#  'عالیست',
#  'بقیه',
#  'یکبار',
#  'می\u200cگذرد',
#  'حرم',
#  'امن',
#  'آقا',
#  'نزدیکه',
#  'لذت',
#  'می\u200cبرم',
#  'شبی',
#  'بردم',
#  'سری',
#  'بزنید',
#  'باسلام',
#  'اتفاق',
#  'ده',
#  'روزه',
#  'تصمیم',
#  'مدت',
#  'قصرطلایی',
#  'سپری',
#  'شود',
#  'ابتدا',
#  'قصر',
#  'طلایی',
#  'اندازه',
#  'تاریک',
#  'وخفه',
#  'زمان',
#  'تخلیه',
#  'نیم',
#  'معطلی',
#  'تازه',
#  'یادشان',
#  'هستیم',
#  'زود\u200cتر',
#  'موعد',
#  'خدمتشان',
#  'مرخص',
#  'شویم',
#  'برگشتیم',
#  'شاپینگ',
#  'سن\u200cتر',
#  'کیلو',
#  'پسته',
#  'خریدم',
#  'داشتند',
#  'چندین',
#  'بخرند',
#  'فروشنده',
#  'زیرکی',
#  'توازن',
#  'نام\u200cگذاری',
#  'لاتین',
#  'برند',
#  'قوی',
#  'آبروی',
#  'ایرانی',
#  'تواضع',
#  'کهنه',
#  'حشره',
#  'موج',
#  'می\u200cزد',
#  'بی\u200cسواد',
#  'فروشگاه',
#  'برادر\u200cبودند',
#  'نخریدم',
#  'خارجی\u200cام',
#  'هرگز',
#  'آزادی',
#  'اسپیناس',
#  'نقل',
#  'مکان',
#  'پارسیان',
#  'استقال',
#  'هتل\u200c\u200cها',
#  'موضوع',
#  'عوامل',
#  'اقدامی',
#  'بروز',
#  'کردن',
#  'نمی\u200cکنند',
#  'حدود',
#  '8',
#  'پیش',
#  'آنچنانی',
#  'مشاهده',
#  'نکردم',
#  'دراین',
#  'هشت',
#  'اضافه\u200cشده\u200cبود',
#  'تلیویزیون',
#  'خودمان',
#  'یک\u200cجوری',
#  'کنار',
#  'می\u200cآییم',
#  'بین\u200cالمللی',
#  'مسافران',
#  'می\u200cآیند',
#  'درخور',
#  'شخصه',
#  'می\u200cدهم',
#  'انشااله',
#  'تغییرات',
#  'باشم',
#  'مسافرت',
#  'میزان',
#  'آرامشی',
#  'استراحت',
#  'استحمام',
#  'لازم\u200cبود',
#  'جدید',
#  'وسایل',
#  'برایم',
#  'تفاوتی',
#  'می\u200cروند',
#  'شخصا',
#  'ترجیح',
#  'استقلال',
#  'برج',
#  'شرقی',
#  'گویا',
#  'نوسازی',
#  'شده\u200cاند',
#  'اما',
#  'کماکان',
#  'نیاز',
#  'دارند',
#  'یخچال',
#  'معلوم',
#  'متعلق',
#  'قرنی',
#  'بهداشتی',
#  'شلنگ',
#  'داشته',
#  'خشک',
#  'کن',
#  'مو',
#  'عنوان',
#  'دیگران',
#  'نیز',
#  'امیدوارم',
#  'بازخورد',
#  'نطر',
#  'مشتریان',
#  'بهسازی',
#  'موثر',
#  'تغییری',
#  'گذشته',
#  'تلویزیون\u200c\u200cها',
#  'دهات',
#  'تایید',
#  'ضمنا',
#  'سونا',
#  'جکوزی',
#  'قبال',
#  'مبلغ',
#  'سی',
#  'هزار',
#  'تومان',
#  'وتعداد',
#  'لوازم',
#  'وموکت\u200cها',
#  'کثیف',
#  'ازنظرنظافت',
#  'تجهیزات',
#  'واثاثیه',
#  'کلا',
#  'توالت',
#  'شیرآلات',
#  'نارضایتیم',
#  'درموقع',
#  'مسئول',
#  'اعلام',
#  'حرفی',
#  'گفتن',
#  'مطلوب',
#  'نام',
#  'دوش',
#  'تجربیات',
#  'خصوص',
#  'نمره',
#  'قبولی',
#  'می\u200cگیرد',
#  'عرض',
#  'تبریک',
#  'اینجانب',
#  ...]

# %% [markdown]
# # save the result

# %%
model.save("word2vec.model")
